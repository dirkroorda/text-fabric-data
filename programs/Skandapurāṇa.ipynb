# %% [markdown]
# <img src="images/skanda.jpg" width="400"/>
# <img src="images/tf-small.png" width="70"/>
#
# # Tutorial
#
# We show a few things that you can do with the Skandapurāṇa corpus in Text-Fabric format.

# %% [markdown]
# # Load modules

# %%
import os
import pickle

# %% [markdown]
# For the next cells you have to install additional Python modules:
#
# ```
# pip3 install python-Levenshtein
# pip3 install text-fabric
# ```

# %%
from Levenshtein import ratio
from tf.fabric import Fabric

# %%
BASE = os.path.expanduser('~/github/Dans-labs/text-fabric-data/sanskrit/sp')
SK = f'{BASE}/tf'
TEMP_DIR = f'{BASE}/_temp'

if not os.path.exists(TEMP_DIR):
  os.makedirs(TEMP_DIR, exist_ok=True)

# %% [markdown]
# # Start Text-Fabric

# %%
TF = Fabric(locations=[SK])
# Out:
# This is Text-Fabric 5.5.18
# Api reference : https://dans-labs.github.io/text-fabric/Api/General/
# Tutorial      : https://github.com/Dans-labs/text-fabric/blob/master/docs/tutorial.ipynb
# Example data  : https://github.com/Dans-labs/text-fabric-data
#
# 11 features found and 0 ignored

# %% [markdown]
# # Load features

# %%
api = TF.load('volume dchar dword tword last number name')
api.makeAvailableIn(locals())
# Out:
#   0.00s loading features ...
#    |     0.00s B name                 from /Users/dirk/github/Dans-labs/text-fabric-data/sanskrit/sp/tf
#    |     0.01s B number               from /Users/dirk/github/Dans-labs/text-fabric-data/sanskrit/sp/tf
#    |     0.14s B dchar                from /Users/dirk/github/Dans-labs/text-fabric-data/sanskrit/sp/tf
#    |     0.03s B dword                from /Users/dirk/github/Dans-labs/text-fabric-data/sanskrit/sp/tf
#    |     0.06s B last                 from /Users/dirk/github/Dans-labs/text-fabric-data/sanskrit/sp/tf
#    |     0.03s B tword                from /Users/dirk/github/Dans-labs/text-fabric-data/sanskrit/sp/tf
#    |     0.00s B volume               from /Users/dirk/github/Dans-labs/text-fabric-data/sanskrit/sp/tf
#   0.71s All features loaded/computed - for details use loadLog()

# %% [markdown]
# # Work
#
# Now we can do real work.
#
# We start with basic exploration.

# %% [markdown]
# # Showing

# %% [markdown]
# Line 2 in verse 3 in document 4:

# %%
node = T.nodeFromSection(('004', 3, 2))
print(T.text(L.d(node, otype='char')))
# Out:
# तेजसा जगदाविश्य आजगाम तदन्तिकम्

# %% [markdown]
# A function to print a line with section indicator.
# The line will be printed both in devanagari and in transcription.

# %%
def printLine(line, caption=False):
  section = T.sectionFromNode(line)
  words = L.d(line, otype='word')
  if caption:
    print('{} {}:{}'.format(*section))
  print(f'  {T.text(words, fmt="text-orig-word")}')
  print(f'  {T.text(words, fmt="text-trans-word")}')

# %% [markdown]
# We print the line with node number 400,000.
# Note that this number has no recognizable meaning, it is just a kind of bar code.

# %%
printLine(400000, caption=True)
# Out:
# 058 2:2
#   सा तुष्टा वरदानेन चिन्तयन्ती तदा वरम्
#   sā tuṣṭā varadānena cintayantī tadā varam

# %% [markdown]
# Text 40, divided in verses and lines:

# %%
def printText(name):
  node = T.nodeFromSection((name,))
  print(f'Text {name}')
  for verse in L.d(node, otype='verse'):
    print(f'verse {F.number.v(verse)}')
    for line in L.d(verse, otype='line'):
      print(f' line {F.number.v(line)}')
      printLine(line)

# %%
printText('040')
# Out:
# Text 040
# verse 1
#  line 0
#   सुशर्मोवाच
#   suśarmovāca
#  line 1
#   अतः परं प्रवक्ष्यामि कुम्भीपाकं महाभयम्
#   ataḥ paraṃ pravakṣyāmi kumbhīpākaṃ mahābhayam
#  line 2
#   श्रोतॄणामपि तत्कालं भयदं ह्यकृतात्मनाम्
#   śrotṝṇāmapi tatkālaṃ bhayadaṃ hyakṛtātmanām
# verse 2
#  line 1
#   आयस्यस्तत्र बह्व्यश्च अञ्जनाचलसंनिभाः
#   āyasyastatra bahvyaśca añjanācalasaṃnibhāḥ
#  line 2
#   कुम्भ्यस्तैलेन संपूर्णा वह्नितप्ताः सुदुःसहाः
#   kumbhyastailena saṃpūrṇā vahnitaptāḥ suduḥsahāḥ
# verse 3
#  line 1
#   दुष्कृतींस्तासु तप्तासु बद्ध्वा बद्ध्वा भयावहाः
#   duṣkṛtīṃstāsu taptāsu baddhvā baddhvā bhayāvahāḥ
#  line 2
#   चरन्ति राक्षसा घोराः क्रन्दमानान्सुभैरवम्
#   caranti rākṣasā ghorāḥ krandamānānsubhairavam
# verse 4
#  line 1
#   वर्षकोटीश्चतस्रश्च पच्यन्ते तत्र जन्तवः
#   varṣakoṭīścatasraśca pacyante tatra jantavaḥ
#  line 2
#   ये तानिमान्निबोध त्वमुच्यमानान्मया विभो
#   ye tānimānnibodha tvamucyamānānmayā vibho
# verse 5
#  line 1
#   इष्टकापाककारी च कुम्भपाचक एव च
#   iṣṭakāpākakārī ca kumbhapācaka eva ca
#  line 2
#   तौ विनाशयते यश्च अग्निदो यो गृहेषु च
#   tau vināśayate yaśca agnido yo gṛheṣu ca
# verse 6
#  line 1
#   वने खले ऽथ गोष्ठे वा अन्नपाकविनाशकः
#   vane khale 'tha goṣṭhe vā annapākavināśakaḥ
#  line 2
#   भोजने विघ्नकारी च यज्ञहा यज्ञदाहकः
#   bhojane vighnakārī ca yajñahā yajñadāhakaḥ
# verse 7
#  line 1
#   कूटकर्मकरो यश्च कूटसाक्षी तथैव च
#   kūṭakarmakaro yaśca kūṭasākṣī tathaiva ca
#  line 2
#   मिथ्याग्निचयनी चैव मिथ्याग्न्याहरणी तथा
#   mithyāgnicayanī caiva mithyāgnyāharaṇī tathā
# verse 8
#  line 1
#   मिथ्यापाकप्रदाता च वेदानां यश्च दूषकः
#   mithyāpākapradātā ca vedānāṃ yaśca dūṣakaḥ
#  line 2
#   हर्तोपकरणानां च शिल्पिनां यो नराधमः
#   hartopakaraṇānāṃ ca śilpināṃ yo narādhamaḥ
# verse 9
#  line 1
#   एवं ते यातितास्तत्र विश्रामं पुनरुच्छ्रये
#   evaṃ te yātitāstatra viśrāmaṃ punarucchraye
#  line 2
#   संप्राप्य नरके भूयो निपतन्ति क्षयान्तिकम्
#   saṃprāpya narake bhūyo nipatanti kṣayāntikam
# verse 10
#  line 1
#   य इमं बहुदुष्कृतान्तपाकं शृणुयान्मनुजो हि कर्मवासम्
#   ya imaṃ bahuduṣkṛtāntapākaṃ śṛṇuyānmanujo hi karmavāsam
#  line 2
#   न स गच्छति तं दुरात्मतापं नरकं कुम्भिसमाख्यमुज्झिताघः
#   na sa gacchati taṃ durātmatāpaṃ narakaṃ kumbhisamākhyamujjhitāghaḥ
# verse 999
#  line 9
#   स्कन्दपुराणे चत्वारिंशो ऽध्यायः
#   skandapurāṇe catvāriṃśo 'dhyāyaḥ

# %% [markdown]
# ## Counting
#
# How many letters?

# %%
len(F.otype.s('char'))
# Out:
# 347770

# %% [markdown]
# How many words?

# %%
len(F.otype.s('word'))
# Out:
# 45101

# %% [markdown]
# How many lines?

# %%
len(F.otype.s('line'))
# Out:
# 10012

# %% [markdown]
# How many verses?

# %%
len(F.otype.s('verse'))
# Out:
# 4532

# %% [markdown]
# How many texts?

# %%
len(F.otype.s('text'))
# Out:
# 75

# %% [markdown]
# Frequency list of the devanagari characters:

# %%
for (d, f) in F.dchar.freqList():
  print(f'{f:>5} x {d}')
# Out:
# 45382 x ्
# 28360 x ा
# 25100 x त
# 19963 x र
# 17067 x व
# 15626 x म
# 15421 x ि
# 15097 x न
# 14838 x य
# 14379 x स
# 10345 x े
#  9746 x द
#  9473 x ु
#  9468 x प
#  9218 x ं
#  8263 x क
#  6714 x च
#  6498 x ः
#  6211 x श
#  5790 x ो
#  4754 x ह
#  4605 x ष
#  4430 x भ
#  4187 x ग
#  3376 x ण
#  3209 x ल
#  3074 x ी
#  2957 x ज
#  2794 x ध
#  2729 x ै
#  2597 x ृ
#  2308 x थ
#  1831 x ू
#  1587 x ब
#  1204 x ट
#   980 x ऽ
#   963 x अ
#   818 x ौ
#   706 x उ
#   655 x ख
#   655 x ञ
#   574 x छ
#   570 x ङ
#   491 x ए
#   436 x इ
#   431 x घ
#   330 x ड
#   311 x ठ
#   295 x आ
#   228 x †
#   218 x फ
#   182 x -
#    90 x ऋ
#    77 x ढ
#    60 x ऊ
#    36 x ॄ
#    26 x ई
#    15 x ऐ
#    13 x झ
#     4 x ओ
#     4 x औ
#     1 x .

# %% [markdown]
# How many distinct words, how many hapaxes, and the frequency list of the top 20:

# %%
freqWords = F.dword.freqList()
print(f'{len(freqWords)} distinct words')
# Out:
# 21980 distinct words

# %%
print()
hapaxes = [x[0] for x in freqWords if x[1] == 1]
print(f'{len(hapaxes)} hapaxes')
print('\n'.join(hapaxes[0:10]))
# Out:
# 17932 hapaxes
# अकम्पनो
# अकरोत्किं
# अकरोत्किमिति
# अकरोदुदकक्रियाम्
# अकरोद्भैरवं
# अकस्मात्सम्प्रदृश्यते
# अकस्मादथ
# अकस्मादभवत्सर्वं
# अकार्याणि
# अकिंचना

# %%
for (d, f) in freqWords[0:20]:
  print(f'{f:>5} x {d}')
# Out:
#  1312 x च
#   527 x स
#   450 x उवाच
#   419 x न
#   330 x ते
#   265 x नमः
#   246 x सनत्कुमार
#   231 x चैव
#   221 x तु
#   195 x तदा
#   191 x तं
#   191 x ततो
#   184 x वै
#   175 x हि
#   166 x तथा
#   162 x -
#   156 x नमो
#   153 x मे
#   142 x तत्र
#   142 x व्यास

# %% [markdown]
# # Parallels
#
# We find parallels between lines.
#
# We compare each pair of lines in the following way:
#
# * the set of devanagari letters occurring in each line is computed;
# * the similarity of two lines is defined as the number of characters;
#   in the intersection of both sets divided by the number of lines in the union of both sets;
# * note that if two lines have the same sets of characters, their similarity is 1;
# * we store the similarity of each pair of lines that are sufficiently similar;
# * we indicate similarity thresholds: numbers between 0 and 1. If two lines have a similarity
#   above the similarity threshold in use, we consider them similar.
# * we play with similarity thresholds and list the similar lines for those thresholds.
#
# ## Discussion
#
# Our similarity measure is blunt: if two lines are composed out of the same set of characters, they are considered 100% similar. We expect to get many false positives.
# We also expect that the real parallels may be obscured by the many false positives.
#
# Yet, we do not know what will happen, so we just start with a coarse but quick method.
# Later, when we refine, we can observe how much more sophistication buys us.
#
# We call the coarse, set-based method `SET`.

# %%
def simSET(a, b): return len(a & b) / len(a | b)

# %% [markdown]
# For the more sophisticated method
# we'll use the module [python-Levenshtein](https://pypi.org/project/python-Levenshtein/)
# and especially its method `ratio()`.
#
# This method gives us similarity in terms of how many edits you need to get from the one string to the other.
# An other way to characterize it, is to say that it gives the ratio between the longest common subsequence of two strings with respect to their individual length.
#
# In the sequel, we call this method `LCS`.
# We do not have to program it, because the Levenshtein module we have imported contains
# an efficient implementation of it: the function `ratio()`.

# %%
simLCS = ratio

# %% [markdown]
# ## Preparation
#
# Comparing all lines with each other takes a lot of computations: roughly 10,000 * 10,000 / 2,
# or 50,000,000.
#
# It pays off to do as little work per similarity comparison.
#
# On beforehand, we map each line node to the set of characters it contains.
#
# We will vary between methods of similarity computation, which will also require different
# preparation routines.
#
# Here we define preparation for the SET method, as outlined above.

# %%
lines = F.otype.s('line')

def prepareSET():
  lineSets = {}
  for line in lines:
    chars = set()
    for word in L.d(line, otype='word'):
      chars |= set(F.dword.v(word))
    lineSets[line] = chars
  return lineSets

# %% [markdown]
# In order to use the LCS method, we need to compare strings.
# We will ignore the spacing between words.
#
# So we define a new preparation step in which for each line its devanagari continuous string value is computed.

# %%
def prepareLCS():
  lineStrings = {}
  for line in lines:
    lineString = ''.join(
      F.dword.v(word)
      for word in L.d(line, otype='word')
    )
    lineStrings[line] = lineString
  return lineStrings

# %%
def prepare(method):
  return prepareSET() if method == 'SET' else prepareLCS()

# %% [markdown]
# If 2 lines are too dissimilar, we will not store their similarity, in order to save space.

# %%
MIN_THRESHOLD = 0.75

# %% [markdown]
# ## Filling the similarity matrix

# %% [markdown]
# Computing the similarity matrix is a bit labor-intensive.
# Before we compute it, we check whether we have computed it before and saved it do disk.
# If so, we load the matrix from there.
# If not, we compute it, and save it to disk.
#
# Note that for each method we compute a separate similarity matrix.

# %%
MATRIX_FILE_BASE = f'{TEMP_DIR}/matrix'

def compare(lineData, method):
  matrixFile = MATRIX_FILE_BASE + method
  sim = simSET if method == 'SET' else simLCS
  indent(reset=True)
  if os.path.exists(matrixFile):
    info(f'Using existing matrix ...')
    with open(matrixFile, 'rb') as mf:
      matrix = pickle.load(mf)
    info(f'{len(matrix)} similarities')
    return matrix
  
  nLines = len(lines)
  matrix = {}
  info(f'{int(nLines * nLines / 2)} comparisons to do')
  c = 0
  k = 0
  chunkSize = 1000000
  info(f'{c:>8} comparisons and {len(matrix):>8} similarities stored')
  for i in range(0, nLines - 1):
    for j in range(i + 1, nLines):
      c += 1
      k += 1
      if k == chunkSize:
        k = 0
        info(f'{c:>8} comparisons and {len(matrix):>8} similarities stored')
      li = lines[i]
      lj = lines[j]
      s = sim(lineData[li], lineData[lj])
      if s >= MIN_THRESHOLD:
        matrix[(li, lj)] = s
  info(f'{c:>8} comparisons and {len(matrix):>8} similarities stored')
  with open(matrixFile, 'wb') as mf:
    pickle.dump(matrix, mf)
  return matrix

# %% [markdown]
# Now together:

# %%
def parallels(method):
  lineData = prepare(method)
  matrix = compare(lineData, method)
  return (lineData, matrix)

# %%
(lineSets, matrixSET) = parallels('SET')
# Out:
#   0.00s Using existing matrix ...
#   0.05s 93603 similarities

# %%
(lineStrings, matrixLCS) = parallels('LCS')
# Out:
#   0.00s Using existing matrix ...
#   0.02s 35177 similarities

# %% [markdown]
# # Exploring the results
#
# We need to filter the matrix in order to focus on the most similar pairs.
#
# The following filter function works for matrices in general.

# %%
def filterMatrix(matrix, threshold):
  return {
    (li, lj, s)
    for ((li, lj), s) in matrix.items()
    if s >= threshold
  }

# %% [markdown]
# # Working with the SET results
#
# We start investigating the results of the SET method.
#
# ## Selecting the most similar lines
#
# We filter the matrix for similarities above a certain threshold.

# %% [markdown]
# How many have similarity 1?

# %%
matrix100 = filterMatrix(matrixSET, 1)
len(matrix100)
# Out:
# 32215

# %% [markdown]
# How many of these are identical pairs?

# %%
def devText(line):
  words = L.d(line, otype='word')
  return T.text(words, fmt='text-orig-word')

def transText(line):
  words = L.d(line, otype='word')
  return T.text(words, fmt='text-trans-word')

def lineEq(li, lj):
  return devText(li) == devText(lj)

matrixEq = {
  (li, lj)
  for (li, lj, s) in matrix100
  if lineEq(li, lj)
}

len(matrixEq)
# Out:
# 32180

# %% [markdown]
# We want to spot interesting similarities.
# But before we do that, we want to get a feeling for all those identical pairs.
#
# How many distinct lines are there with multiple occurrences in the corpus?

# %%
repeatedLines = {devText(li) for (li, lj) in matrixEq}
len(repeatedLines)
# Out:
# 66

# %% [markdown]
# So, there are very few distinct lines that are repeated verbatim, but those are repeated pretty many times. Here they are:

# %%
print('\n'.join(sorted(repeatedLines)))
# Out:
# - - - - - - - - - - - - - - - -
# अभितः स्तूयमानश्च सूतमागधवन्दिभिः
# अभेद्यश्चैव वज्रेण मत्प्रसादाद्भविष्यसि
# अमरो जरया त्यक्तः सर्वदुःखविवर्जितः
# उपमन्युरुवाच
# उशीरबीजः शैलेन्द्रस्तत्राश्रमपदं महत्
# ऋषय ऊचुः
# कारोहणमिति ख्यातं त्रिनेत्रायतनं महत्
# काष्ठकूट उवाच
# कुबेर उवाच
# कृमिकीटेषु जायन्ते सहस्राणां शतानि षट्
# ग्राह उवाच
# चतुर्थेनावतस्थे च यतः स भगवान्प्रभुः
# छगलण्डेश्वरे चैव महाभैरवजं फलम्
# जैगीषव्य उवाच
# तस्मिंश्चन्द्रप्रभं लिङ्गं स्फाटिकं मणिरञ्जितम्
# तृतीयश्चाभवन्मित्रो मथुरायां महामनाः
# त्रेतायां दिण्डिमुण्डश्च शिरांसि विनिकृत्तवान्
# दक्ष उवाच
# दधीच उवाच
# दधीचेन महद्दिव्यं पुण्यमायतनं कृतम्
# देव उवाच
# देवा ऊचुः
# देव्युवाच
# द्वितीयं द्वापरे प्राप्ते तृतीयं च कलौ युगे
# नन्द्युवाच
# नमः सहस्रनेत्राय शतनेत्राय वै नमः
# नमस्ते सर्वलोकेश नमस्ते लोकभावन
# पात्यन्ते विवशा मूढा यावत्पापं क्षयं गतम्
# पितर ऊचुः
# पितामह उवाच
# पुण्यमायतनं तत्र च्यवनेनाभिनिर्मितम्
# पुष्पभद्रमिति ख्यातं विन्ध्यप्रस्थे द्रुमावृतम्
# ब्रह्मचारी चतुर्थस्तु कुरुष्वेव सुगोत्रजः
# ब्रह्मोवाच
# भगवन्यदि तुष्टो ऽसि यदि देयो वरश्च मे
# भगवानपि देवेशः परमैश्वर्यसंयुतः
# भगवानुवाच
# भवस्यायतनं पुण्यं देवगन्धर्वसेवितम्
# भारं बद्ध्वा द्विजातीनां नर्मदायां विचिक्षिपे
# भास्करानलसंकाशा निवसन्ति तपोधनाः
# यज्ञ उवाच
# यत्तद्रावणपुत्रेण मेघनादेन रक्षसा
# यत्र कः कां तपस्यन्तीमारुरोह प्रजापतिः
# यत्र ते मुनयः सत्याः सत्यानलरविप्रभाः
# यत्र भस्त्रेश्वरं नाम रुद्रस्यायतनं शुभम्
# यशोवाच
# यैस्तदायतनं दृष्टं कुबेरस्य सुरासुरैः
# राजोवाच
# वसिष्ठ उवाच
# वायुरुवाच
# विप्र उवाच
# विश्रान्तास्तत्र ते गत्वा उच्छ्रयान्नरकं पुनः
# विष्णुरुवाच
# व्यास उवाच
# शक्र उवाच
# शिलाद उवाच
# सनत्कुमार उवाच
# सम्यगिष्टे तु यत्प्रोक्तमश्वमेधे फलं बुधैः
# सर्वपापविनिर्मुक्तो रुद्रलोकमवाप्नुयात्
# सहस्रं स्थापितं व्यास शिलादेन महात्मना
# सुकेश उवाच
# सुधर्मोवाच
# सुशर्मोवाच
# सो ऽश्वमेधफलं प्राप्य रुद्रलोके महीयते
# स्थापितं सुमहल्लिङ्गं देवदेवस्य शूलिनः

# %% [markdown]
# Let's get the transcriptions as well, plus the number of times each line is repeated.

# %%
repeatedOccs = {}
for l in lines:
  d = devText(l)
  if d in repeatedLines:
    repeatedOccs.setdefault(d, set()).add(l)

# %%
for (repeated, occs) in sorted(
  repeatedOccs.items(), 
  key=lambda x: -len(x[1]),
):
  print(f'{len(occs):>3} x\n\t{repeated}\n\t{transText(sorted(occs)[0])}')
# Out:
# 246 x
# 	सनत्कुमार उवाच
# 	sanatkumāra uvāca
#  38 x
# 	देव उवाच
# 	deva uvāca
#  30 x
# 	व्यास उवाच
# 	vyāsa uvāca
#  26 x
# 	देव्युवाच
# 	devyuvāca
#  21 x
# 	ब्रह्मोवाच
# 	brahmovāca
#  15 x
# 	सुशर्मोवाच
# 	suśarmovāca
#  11 x
# 	पितर ऊचुः
# 	pitara ūcuḥ
#   8 x
# 	वायुरुवाच
# 	vāyuruvāca
#   8 x
# 	नन्द्युवाच
# 	nandyuvāca
#   7 x
# 	- - - - - - - - - - - - - - - -
# 	- - - - - - - - - - - - - - - -
#   7 x
# 	उपमन्युरुवाच
# 	upamanyuruvāca
#   6 x
# 	देवा ऊचुः
# 	devā ūcuḥ
#   6 x
# 	सुकेश उवाच
# 	sukeśa uvāca
#   4 x
# 	पितामह उवाच
# 	pitāmaha uvāca
#   4 x
# 	शिलाद उवाच
# 	śilāda uvāca
#   4 x
# 	काष्ठकूट उवाच
# 	kāṣṭhakūṭa uvāca
#   3 x
# 	ऋषय ऊचुः
# 	ṛṣaya ūcuḥ
#   3 x
# 	विष्णुरुवाच
# 	viṣṇuruvāca
#   3 x
# 	ग्राह उवाच
# 	grāha uvāca
#   3 x
# 	वसिष्ठ उवाच
# 	vasiṣṭha uvāca
#   3 x
# 	भगवानुवाच
# 	bhagavānuvāca
#   3 x
# 	राजोवाच
# 	rājovāca
#   3 x
# 	शक्र उवाच
# 	śakra uvāca
#   3 x
# 	अमरो जरया त्यक्तः सर्वदुःखविवर्जितः
# 	amaro jarayā tyaktaḥ sarvaduḥkhavivarjitaḥ
#   2 x
# 	नमः सहस्रनेत्राय शतनेत्राय वै नमः
# 	namaḥ sahasranetrāya śatanetrāya vai namaḥ
#   2 x
# 	सर्वपापविनिर्मुक्तो रुद्रलोकमवाप्नुयात्
# 	sarvapāpavinirmukto rudralokamavāpnuyāt
#   2 x
# 	भगवन्यदि तुष्टो ऽसि यदि देयो वरश्च मे
# 	bhagavanyadi tuṣṭo 'si yadi deyo varaśca me
#   2 x
# 	नमस्ते सर्वलोकेश नमस्ते लोकभावन
# 	namaste sarvalokeśa namaste lokabhāvana
#   2 x
# 	सो ऽश्वमेधफलं प्राप्य रुद्रलोके महीयते
# 	so 'śvamedhaphalaṃ prāpya rudraloke mahīyate
#   2 x
# 	जैगीषव्य उवाच
# 	jaigīṣavya uvāca
#   2 x
# 	कुबेर उवाच
# 	kubera uvāca
#   2 x
# 	अभेद्यश्चैव वज्रेण मत्प्रसादाद्भविष्यसि
# 	abhedyaścaiva vajreṇa matprasādādbhaviṣyasi
#   2 x
# 	यज्ञ उवाच
# 	yajña uvāca
#   2 x
# 	दधीच उवाच
# 	dadhīca uvāca
#   2 x
# 	दक्ष उवाच
# 	dakṣa uvāca
#   2 x
# 	विप्र उवाच
# 	vipra uvāca
#   2 x
# 	विश्रान्तास्तत्र ते गत्वा उच्छ्रयान्नरकं पुनः
# 	viśrāntāstatra te gatvā ucchrayānnarakaṃ punaḥ
#   2 x
# 	पात्यन्ते विवशा मूढा यावत्पापं क्षयं गतम्
# 	pātyante vivaśā mūḍhā yāvatpāpaṃ kṣayaṃ gatam
#   2 x
# 	कृमिकीटेषु जायन्ते सहस्राणां शतानि षट्
# 	kṛmikīṭeṣu jāyante sahasrāṇāṃ śatāni ṣaṭ
#   2 x
# 	यशोवाच
# 	yaśovāca
#   2 x
# 	सुधर्मोवाच
# 	sudharmovāca
#   2 x
# 	अभितः स्तूयमानश्च सूतमागधवन्दिभिः
# 	abhitaḥ stūyamānaśca sūtamāgadhavandibhiḥ
#   2 x
# 	पुण्यमायतनं तत्र च्यवनेनाभिनिर्मितम्
# 	puṇyamāyatanaṃ tatra cyavanenābhinirmitam
#   2 x
# 	यत्र ते मुनयः सत्याः सत्यानलरविप्रभाः
# 	yatra te munayaḥ satyāḥ satyānalaraviprabhāḥ
#   2 x
# 	उशीरबीजः शैलेन्द्रस्तत्राश्रमपदं महत्
# 	uśīrabījaḥ śailendrastatrāśramapadaṃ mahat
#   2 x
# 	स्थापितं सुमहल्लिङ्गं देवदेवस्य शूलिनः
# 	sthāpitaṃ sumahalliṅgaṃ devadevasya śūlinaḥ
#   2 x
# 	तस्मिंश्चन्द्रप्रभं लिङ्गं स्फाटिकं मणिरञ्जितम्
# 	tasmiṃścandraprabhaṃ liṅgaṃ sphāṭikaṃ maṇirañjitam
#   2 x
# 	यैस्तदायतनं दृष्टं कुबेरस्य सुरासुरैः
# 	yaistadāyatanaṃ dṛṣṭaṃ kuberasya surāsuraiḥ
#   2 x
# 	यत्र भस्त्रेश्वरं नाम रुद्रस्यायतनं शुभम्
# 	yatra bhastreśvaraṃ nāma rudrasyāyatanaṃ śubham
#   2 x
# 	छगलण्डेश्वरे चैव महाभैरवजं फलम्
# 	chagalaṇḍeśvare caiva mahābhairavajaṃ phalam
#   2 x
# 	भास्करानलसंकाशा निवसन्ति तपोधनाः
# 	bhāskarānalasaṃkāśā nivasanti tapodhanāḥ
#   2 x
# 	दधीचेन महद्दिव्यं पुण्यमायतनं कृतम्
# 	dadhīcena mahaddivyaṃ puṇyamāyatanaṃ kṛtam
#   2 x
# 	पुष्पभद्रमिति ख्यातं विन्ध्यप्रस्थे द्रुमावृतम्
# 	puṣpabhadramiti khyātaṃ vindhyaprasthe drumāvṛtam
#   2 x
# 	भवस्यायतनं पुण्यं देवगन्धर्वसेवितम्
# 	bhavasyāyatanaṃ puṇyaṃ devagandharvasevitam
#   2 x
# 	यत्तद्रावणपुत्रेण मेघनादेन रक्षसा
# 	yattadrāvaṇaputreṇa meghanādena rakṣasā
#   2 x
# 	सम्यगिष्टे तु यत्प्रोक्तमश्वमेधे फलं बुधैः
# 	samyagiṣṭe tu yatproktamaśvamedhe phalaṃ budhaiḥ
#   2 x
# 	सहस्रं स्थापितं व्यास शिलादेन महात्मना
# 	sahasraṃ sthāpitaṃ vyāsa śilādena mahātmanā
#   2 x
# 	कारोहणमिति ख्यातं त्रिनेत्रायतनं महत्
# 	kārohaṇamiti khyātaṃ trinetrāyatanaṃ mahat
#   2 x
# 	यत्र कः कां तपस्यन्तीमारुरोह प्रजापतिः
# 	yatra kaḥ kāṃ tapasyantīmāruroha prajāpatiḥ
#   2 x
# 	द्वितीयं द्वापरे प्राप्ते तृतीयं च कलौ युगे
# 	dvitīyaṃ dvāpare prāpte tṛtīyaṃ ca kalau yuge
#   2 x
# 	चतुर्थेनावतस्थे च यतः स भगवान्प्रभुः
# 	caturthenāvatasthe ca yataḥ sa bhagavānprabhuḥ
#   2 x
# 	भारं बद्ध्वा द्विजातीनां नर्मदायां विचिक्षिपे
# 	bhāraṃ baddhvā dvijātīnāṃ narmadāyāṃ vicikṣipe
#   2 x
# 	त्रेतायां दिण्डिमुण्डश्च शिरांसि विनिकृत्तवान्
# 	tretāyāṃ diṇḍimuṇḍaśca śirāṃsi vinikṛttavān
#   2 x
# 	तृतीयश्चाभवन्मित्रो मथुरायां महामनाः
# 	tṛtīyaścābhavanmitro mathurāyāṃ mahāmanāḥ
#   2 x
# 	ब्रह्मचारी चतुर्थस्तु कुरुष्वेव सुगोत्रजः
# 	brahmacārī caturthastu kuruṣveva sugotrajaḥ
#   2 x
# 	भगवानपि देवेशः परमैश्वर्यसंयुतः
# 	bhagavānapi deveśaḥ paramaiśvaryasaṃyutaḥ

# %% [markdown]
# We continue with the non-identical pairs.
#
# Our first attempt is to see what the 100 most similar
# pairs are, excluding the identical pairs.
#
# It turns out that most of them are between the last lines of texts,
# which are apparently stating the ordinal number of the text within the corpus.
#
# So in the second attempt, we'll exclude these lines, they all have verse number 999.

# %%
similars = []
for (li, lj, s) in sorted(
  filterMatrix(matrixSET, 0.95),
  key=lambda x: -x[2],
):
  if (li, lj) in matrixEq: continue
  if len(similars) >= 100:
    break
  similars.append((li, lj, s))
print(f'Collected {len(similars)} pairs')
# Out:
# Collected 100 pairs

# %%
for (li, lj, s) in similars: 
  print(f'similarity {s}:')
  printLine(li, caption=True)
  printLine(lj, caption=True)
  print()
# Out:
# similarity 1.0:
# 020 999:9
#   इति स्कन्दपुराणे विंशतितमो ऽध्यायः
#   iti skandapurāṇe viṃśatitamo 'dhyāyaḥ
# 027 999:9
#   इति स्कन्दपुराणे सप्तविंशतितमो ऽध्यायः
#   iti skandapurāṇe saptaviṃśatitamo 'dhyāyaḥ
#
# similarity 1.0:
# 013 999:9
#   इति स्कन्दपुराणे नाम त्रयोदशो ऽध्यायः
#   iti skandapurāṇe nāma trayodaśo 'dhyāyaḥ
# 017 999:9
#   इति स्कन्दपुराणे सप्तदशमो ऽध्यायः
#   iti skandapurāṇe saptadaśamo 'dhyāyaḥ
#
# similarity 1.0:
# 018 999:9
#   इति स्कन्दपुराणे ऽष्टादशमो ऽध्यायः
#   iti skandapurāṇe 'ṣṭādaśamo 'dhyāyaḥ
# 167S 999:9
#   इति स्कन्दपुराणे सप्तषष्ट्युत्तरशततमो ऽध्यायः
#   iti skandapurāṇe saptaṣaṣṭyuttaraśatatamo 'dhyāyaḥ
#
# similarity 1.0:
# 042 999:9
#   स्कन्दपुराणे द्वाचत्वारिंशो ऽध्यायः
#   skandapurāṇe dvācatvāriṃśo 'dhyāyaḥ
# 047 999:9
#   स्कन्दपुराणे सप्तचत्वारिंशो ऽध्यायः
#   skandapurāṇe saptacatvāriṃśo 'dhyāyaḥ
#
# similarity 1.0:
# 040 999:9
#   स्कन्दपुराणे चत्वारिंशो ऽध्यायः
#   skandapurāṇe catvāriṃśo 'dhyāyaḥ
# 044 999:9
#   स्कन्दपुराणे चतुश्चत्वारिंशो ऽध्यायः
#   skandapurāṇe catuścatvāriṃśo 'dhyāyaḥ
#
# similarity 1.0:
# 046 999:9
#   स्कन्दपुराणे षट्चत्वारिंशो ऽध्यायः
#   skandapurāṇe ṣaṭcatvāriṃśo 'dhyāyaḥ
# 048 999:9
#   स्कन्दपुराणे ऽष्टचत्वारिंशो ऽध्यायः
#   skandapurāṇe 'ṣṭacatvāriṃśo 'dhyāyaḥ
#
# similarity 1.0:
# 040 999:9
#   स्कन्दपुराणे चत्वारिंशो ऽध्यायः
#   skandapurāṇe catvāriṃśo 'dhyāyaḥ
# 047 999:9
#   स्कन्दपुराणे सप्तचत्वारिंशो ऽध्यायः
#   skandapurāṇe saptacatvāriṃśo 'dhyāyaḥ
#
# similarity 1.0:
# 020 999:9
#   इति स्कन्दपुराणे विंशतितमो ऽध्यायः
#   iti skandapurāṇe viṃśatitamo 'dhyāyaḥ
# 023 999:9
#   इति स्कन्दपुराणे त्रयोविंशतिमो ऽध्यायः
#   iti skandapurāṇe trayoviṃśatimo 'dhyāyaḥ
#
# similarity 1.0:
# 036 999:9
#   स्कन्दपुराणे षट्त्रिंशत्तमो ऽध्यायः
#   skandapurāṇe ṣaṭtriṃśattamo 'dhyāyaḥ
# 038 999:9
#   स्कन्दपुराणे ऽष्टत्रिंशत्तमो ऽध्यायः
#   skandapurāṇe 'ṣṭatriṃśattamo 'dhyāyaḥ
#
# similarity 1.0:
# 022 999:9
#   इति स्कन्दपुराणे द्वाविंशतिमो ऽध्यायः
#   iti skandapurāṇe dvāviṃśatimo 'dhyāyaḥ
# 027 999:9
#   इति स्कन्दपुराणे सप्तविंशतितमो ऽध्यायः
#   iti skandapurāṇe saptaviṃśatitamo 'dhyāyaḥ
#
# similarity 1.0:
# 012 36:1
#   श्रुत्वा तु देवी तं नादं विप्रस्यार्तस्य शोभना
#   śrutvā tu devī taṃ nādaṃ viprasyārtasya śobhanā
# 028 1:1
#   ततो व्यास पुनर्देवी पतिं व्रतपतिं शुभा
#   tato vyāsa punardevī patiṃ vratapatiṃ śubhā
#
# similarity 1.0:
# 053 999:9
#   इति स्कन्दपुराणे त्रिपञ्चाशो ऽध्यायः
#   iti skandapurāṇe tripañcāśo 'dhyāyaḥ
# 055 999:9
#   इति स्कन्दपुराणे पञ्चपञ्चाशो ऽध्यायः
#   iti skandapurāṇe pañcapañcāśo 'dhyāyaḥ
#
# similarity 1.0:
# 063 999:9
#   इति स्कन्दपुराणे त्रिषष्टो ऽध्यायः
#   iti skandapurāṇe triṣaṣṭo 'dhyāyaḥ
# 066 999:9
#   इति स्कन्दपुराणे षट्षष्टो ऽध्यायः
#   iti skandapurāṇe ṣaṭṣaṣṭo 'dhyāyaḥ
#
# similarity 1.0:
# 042 999:9
#   स्कन्दपुराणे द्वाचत्वारिंशो ऽध्यायः
#   skandapurāṇe dvācatvāriṃśo 'dhyāyaḥ
# 044 999:9
#   स्कन्दपुराणे चतुश्चत्वारिंशो ऽध्यायः
#   skandapurāṇe catuścatvāriṃśo 'dhyāyaḥ
#
# similarity 1.0:
# 040 999:9
#   स्कन्दपुराणे चत्वारिंशो ऽध्यायः
#   skandapurāṇe catvāriṃśo 'dhyāyaḥ
# 042 999:9
#   स्कन्दपुराणे द्वाचत्वारिंशो ऽध्यायः
#   skandapurāṇe dvācatvāriṃśo 'dhyāyaḥ
#
# similarity 1.0:
# 040 999:9
#   स्कन्दपुराणे चत्वारिंशो ऽध्यायः
#   skandapurāṇe catvāriṃśo 'dhyāyaḥ
# 043 999:9
#   स्कन्दपुराणे त्रयश्चत्वारिंशो ऽध्यायः
#   skandapurāṇe trayaścatvāriṃśo 'dhyāyaḥ
#
# similarity 1.0:
# 043 999:9
#   स्कन्दपुराणे त्रयश्चत्वारिंशो ऽध्यायः
#   skandapurāṇe trayaścatvāriṃśo 'dhyāyaḥ
# 047 999:9
#   स्कन्दपुराणे सप्तचत्वारिंशो ऽध्यायः
#   skandapurāṇe saptacatvāriṃśo 'dhyāyaḥ
#
# similarity 1.0:
# 020 999:9
#   इति स्कन्दपुराणे विंशतितमो ऽध्यायः
#   iti skandapurāṇe viṃśatitamo 'dhyāyaḥ
# 022 999:9
#   इति स्कन्दपुराणे द्वाविंशतिमो ऽध्यायः
#   iti skandapurāṇe dvāviṃśatimo 'dhyāyaḥ
#
# similarity 1.0:
# 044 999:9
#   स्कन्दपुराणे चतुश्चत्वारिंशो ऽध्यायः
#   skandapurāṇe catuścatvāriṃśo 'dhyāyaḥ
# 047 999:9
#   स्कन्दपुराणे सप्तचत्वारिंशो ऽध्यायः
#   skandapurāṇe saptacatvāriṃśo 'dhyāyaḥ
#
# similarity 1.0:
# 022 999:9
#   इति स्कन्दपुराणे द्वाविंशतिमो ऽध्यायः
#   iti skandapurāṇe dvāviṃśatimo 'dhyāyaḥ
# 023 999:9
#   इति स्कन्दपुराणे त्रयोविंशतिमो ऽध्यायः
#   iti skandapurāṇe trayoviṃśatimo 'dhyāyaḥ
#
# similarity 1.0:
# 043 999:9
#   स्कन्दपुराणे त्रयश्चत्वारिंशो ऽध्यायः
#   skandapurāṇe trayaścatvāriṃśo 'dhyāyaḥ
# 044 999:9
#   स्कन्दपुराणे चतुश्चत्वारिंशो ऽध्यायः
#   skandapurāṇe catuścatvāriṃśo 'dhyāyaḥ
#
# similarity 1.0:
# 063 999:9
#   इति स्कन्दपुराणे त्रिषष्टो ऽध्यायः
#   iti skandapurāṇe triṣaṣṭo 'dhyāyaḥ
# 067 999:9
#   इति स्कन्दपुराणे सप्तषष्टो ऽध्यायः
#   iti skandapurāṇe saptaṣaṣṭo 'dhyāyaḥ
#
# similarity 1.0:
# 010 999:9
#   इति स्कन्दपुराणे दशमो ऽध्यायः
#   iti skandapurāṇe daśamo 'dhyāyaḥ
# 017 999:9
#   इति स्कन्दपुराणे सप्तदशमो ऽध्यायः
#   iti skandapurāṇe saptadaśamo 'dhyāyaḥ
#
# similarity 1.0:
# 066 999:9
#   इति स्कन्दपुराणे षट्षष्टो ऽध्यायः
#   iti skandapurāṇe ṣaṭṣaṣṭo 'dhyāyaḥ
# 067 999:9
#   इति स्कन्दपुराणे सप्तषष्टो ऽध्यायः
#   iti skandapurāṇe saptaṣaṣṭo 'dhyāyaḥ
#
# similarity 1.0:
# 010 999:9
#   इति स्कन्दपुराणे दशमो ऽध्यायः
#   iti skandapurāṇe daśamo 'dhyāyaḥ
# 013 999:9
#   इति स्कन्दपुराणे नाम त्रयोदशो ऽध्यायः
#   iti skandapurāṇe nāma trayodaśo 'dhyāyaḥ
#
# similarity 1.0:
# 167S 95:1
#   अन्यदुक्तरथं नाम भवस्यायतनं शुभम्
#   anyaduktarathaṃ nāma bhavasyāyatanaṃ śubham
# 167RA5 17:1
#   अन्यद्युक्तरथं नाम भवस्यायतनं शुभम्
#   anyadyuktarathaṃ nāma bhavasyāyatanaṃ śubham
#
# similarity 1.0:
# 023 999:9
#   इति स्कन्दपुराणे त्रयोविंशतिमो ऽध्यायः
#   iti skandapurāṇe trayoviṃśatimo 'dhyāyaḥ
# 027 999:9
#   इति स्कन्दपुराणे सप्तविंशतितमो ऽध्यायः
#   iti skandapurāṇe saptaviṃśatitamo 'dhyāyaḥ
#
# similarity 1.0:
# 055 999:9
#   इति स्कन्दपुराणे पञ्चपञ्चाशो ऽध्यायः
#   iti skandapurāṇe pañcapañcāśo 'dhyāyaḥ
# 057 999:9
#   इति स्कन्दपुराणे सप्तपञ्चाशो ऽध्यायः
#   iti skandapurāṇe saptapañcāśo 'dhyāyaḥ
#
# similarity 1.0:
# 053 999:9
#   इति स्कन्दपुराणे त्रिपञ्चाशो ऽध्यायः
#   iti skandapurāṇe tripañcāśo 'dhyāyaḥ
# 057 999:9
#   इति स्कन्दपुराणे सप्तपञ्चाशो ऽध्यायः
#   iti skandapurāṇe saptapañcāśo 'dhyāyaḥ
#
# similarity 1.0:
# 063 999:9
#   इति स्कन्दपुराणे त्रिषष्टो ऽध्यायः
#   iti skandapurāṇe triṣaṣṭo 'dhyāyaḥ
# 068 999:9
#   इति स्कन्दपुराणे ऽष्टषष्टो ऽध्यायः
#   iti skandapurāṇe 'ṣṭaṣaṣṭo 'dhyāyaḥ
#
# similarity 1.0:
# 042 999:9
#   स्कन्दपुराणे द्वाचत्वारिंशो ऽध्यायः
#   skandapurāṇe dvācatvāriṃśo 'dhyāyaḥ
# 043 999:9
#   स्कन्दपुराणे त्रयश्चत्वारिंशो ऽध्यायः
#   skandapurāṇe trayaścatvāriṃśo 'dhyāyaḥ
#
# similarity 1.0:
# 033 115:1
#   निवासार्थं च दिव्यं तमिन्द्रद्वीपं ददामि ते
#   nivāsārthaṃ ca divyaṃ tamindradvīpaṃ dadāmi te
# 041 17:2
#   स्वस्थानं च समासीनांस्त्रासयेद्वारयेदपि
#   svasthānaṃ ca samāsīnāṃstrāsayedvārayedapi
#
# similarity 1.0:
# 167S 105:1
#   एको राक्षसशार्दूलो यत्राद्यापि विभीषणः
#   eko rākṣasaśārdūlo yatrādyāpi vibhīṣaṇaḥ
# 167RA5 31:1
#   एत्य राक्षसशार्दूलो यत्राद्यापि विभीषणः
#   etya rākṣasaśārdūlo yatrādyāpi vibhīṣaṇaḥ
#
# similarity 1.0:
# 066 999:9
#   इति स्कन्दपुराणे षट्षष्टो ऽध्यायः
#   iti skandapurāṇe ṣaṭṣaṣṭo 'dhyāyaḥ
# 068 999:9
#   इति स्कन्दपुराणे ऽष्टषष्टो ऽध्यायः
#   iti skandapurāṇe 'ṣṭaṣaṣṭo 'dhyāyaḥ
#
# similarity 1.0:
# 067 999:9
#   इति स्कन्दपुराणे सप्तषष्टो ऽध्यायः
#   iti skandapurāṇe saptaṣaṣṭo 'dhyāyaḥ
# 068 999:9
#   इति स्कन्दपुराणे ऽष्टषष्टो ऽध्यायः
#   iti skandapurāṇe 'ṣṭaṣaṣṭo 'dhyāyaḥ
#
# similarity 0.96:
# 024 999:9
#   इति स्कन्दपुराणे चतुर्विंशतिमो ऽध्यायः
#   iti skandapurāṇe caturviṃśatimo 'dhyāyaḥ
# 025 999:9
#   इति स्कन्दपुराणे पञ्चविंशतिमो ऽध्यायः
#   iti skandapurāṇe pañcaviṃśatimo 'dhyāyaḥ
#
# similarity 0.9583333333333334:
# 020 999:9
#   इति स्कन्दपुराणे विंशतितमो ऽध्यायः
#   iti skandapurāṇe viṃśatitamo 'dhyāyaḥ
# 024 999:9
#   इति स्कन्दपुराणे चतुर्विंशतिमो ऽध्यायः
#   iti skandapurāṇe caturviṃśatimo 'dhyāyaḥ
#
# similarity 0.9583333333333334:
# 019 999:9
#   इति स्कन्दपुराणे ऊनविंशतितमो ऽध्यायः
#   iti skandapurāṇe ūnaviṃśatitamo 'dhyāyaḥ
# 022 999:9
#   इति स्कन्दपुराणे द्वाविंशतिमो ऽध्यायः
#   iti skandapurāṇe dvāviṃśatimo 'dhyāyaḥ
#
# similarity 0.9583333333333334:
# 019 999:9
#   इति स्कन्दपुराणे ऊनविंशतितमो ऽध्यायः
#   iti skandapurāṇe ūnaviṃśatitamo 'dhyāyaḥ
# 027 999:9
#   इति स्कन्दपुराणे सप्तविंशतितमो ऽध्यायः
#   iti skandapurāṇe saptaviṃśatitamo 'dhyāyaḥ
#
# similarity 0.9583333333333334:
# 019 999:9
#   इति स्कन्दपुराणे ऊनविंशतितमो ऽध्यायः
#   iti skandapurāṇe ūnaviṃśatitamo 'dhyāyaḥ
# 023 999:9
#   इति स्कन्दपुराणे त्रयोविंशतिमो ऽध्यायः
#   iti skandapurāṇe trayoviṃśatimo 'dhyāyaḥ
#
# similarity 0.9583333333333334:
# 019 999:9
#   इति स्कन्दपुराणे ऊनविंशतितमो ऽध्यायः
#   iti skandapurāṇe ūnaviṃśatitamo 'dhyāyaḥ
# 020 999:9
#   इति स्कन्दपुराणे विंशतितमो ऽध्यायः
#   iti skandapurāṇe viṃśatitamo 'dhyāyaḥ
#
# similarity 0.9583333333333334:
# 022 999:9
#   इति स्कन्दपुराणे द्वाविंशतिमो ऽध्यायः
#   iti skandapurāṇe dvāviṃśatimo 'dhyāyaḥ
# 024 999:9
#   इति स्कन्दपुराणे चतुर्विंशतिमो ऽध्यायः
#   iti skandapurāṇe caturviṃśatimo 'dhyāyaḥ
#
# similarity 0.9583333333333334:
# 054 999:9
#   इति स्कन्दपुराणे चतुष्पञ्चाशो ऽध्यायः
#   iti skandapurāṇe catuṣpañcāśo 'dhyāyaḥ
# 056 999:9
#   इति स्कन्दपुराणे षट्पञ्चाशो ऽध्यायः
#   iti skandapurāṇe ṣaṭpañcāśo 'dhyāyaḥ
#
# similarity 0.9583333333333334:
# 024 999:9
#   इति स्कन्दपुराणे चतुर्विंशतिमो ऽध्यायः
#   iti skandapurāṇe caturviṃśatimo 'dhyāyaḥ
# 027 999:9
#   इति स्कन्दपुराणे सप्तविंशतितमो ऽध्यायः
#   iti skandapurāṇe saptaviṃśatitamo 'dhyāyaḥ
#
# similarity 0.9583333333333334:
# 023 999:9
#   इति स्कन्दपुराणे त्रयोविंशतिमो ऽध्यायः
#   iti skandapurāṇe trayoviṃśatimo 'dhyāyaḥ
# 024 999:9
#   इति स्कन्दपुराणे चतुर्विंशतिमो ऽध्यायः
#   iti skandapurāṇe caturviṃśatimo 'dhyāyaḥ
#
# similarity 0.9583333333333334:
# 056 999:9
#   इति स्कन्दपुराणे षट्पञ्चाशो ऽध्यायः
#   iti skandapurāṇe ṣaṭpañcāśo 'dhyāyaḥ
# 065 999:9
#   इति स्कन्दपुराणे पञ्चषष्टो ऽध्यायः
#   iti skandapurāṇe pañcaṣaṣṭo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 005 999:9
#   इति स्कन्दपुराणे पञ्चमो ऽध्यायः
#   iti skandapurāṇe pañcamo 'dhyāyaḥ
# 015 999:9
#   इति स्कन्दपुराणे पञ्चदशमो ऽध्यायः
#   iti skandapurāṇe pañcadaśamo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 043 999:9
#   स्कन्दपुराणे त्रयश्चत्वारिंशो ऽध्यायः
#   skandapurāṇe trayaścatvāriṃśo 'dhyāyaḥ
# 045 999:9
#   स्कन्दपुराणे पञ्चचत्वारिंशो ऽध्यायः
#   skandapurāṇe pañcacatvāriṃśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 018 999:9
#   इति स्कन्दपुराणे ऽष्टादशमो ऽध्यायः
#   iti skandapurāṇe 'ṣṭādaśamo 'dhyāyaḥ
# 060 999:9
#   इति स्कन्दपुराणे षष्टितमो ऽध्यायः
#   iti skandapurāṇe ṣaṣṭitamo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 015 999:9
#   इति स्कन्दपुराणे पञ्चदशमो ऽध्यायः
#   iti skandapurāṇe pañcadaśamo 'dhyāyaḥ
# 053 999:9
#   इति स्कन्दपुराणे त्रिपञ्चाशो ऽध्यायः
#   iti skandapurāṇe tripañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 035 999:9
#   इति स्कन्दपुराणे पञ्चत्रिंशो ऽध्यायः
#   iti skandapurāṇe pañcatriṃśo 'dhyāyaḥ
# 055 999:9
#   इति स्कन्दपुराणे पञ्चपञ्चाशो ऽध्यायः
#   iti skandapurāṇe pañcapañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 052 999:9
#   इति स्कन्दपुराणे द्विपञ्चाशो ऽध्यायः
#   iti skandapurāṇe dvipañcāśo 'dhyāyaḥ
# 055 999:9
#   इति स्कन्दपुराणे पञ्चपञ्चाशो ऽध्यायः
#   iti skandapurāṇe pañcapañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 022 999:9
#   इति स्कन्दपुराणे द्वाविंशतिमो ऽध्यायः
#   iti skandapurāṇe dvāviṃśatimo 'dhyāyaḥ
# 030 999:9
#   इति स्कन्दपुराणे त्रिंशत्तमो ऽध्यायः
#   iti skandapurāṇe triṃśattamo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 023 999:9
#   इति स्कन्दपुराणे त्रयोविंशतिमो ऽध्यायः
#   iti skandapurāṇe trayoviṃśatimo 'dhyāyaḥ
# 030 999:9
#   इति स्कन्दपुराणे त्रिंशत्तमो ऽध्यायः
#   iti skandapurāṇe triṃśattamo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 027 999:9
#   इति स्कन्दपुराणे सप्तविंशतितमो ऽध्यायः
#   iti skandapurāṇe saptaviṃśatitamo 'dhyāyaḥ
# 030 999:9
#   इति स्कन्दपुराणे त्रिंशत्तमो ऽध्यायः
#   iti skandapurāṇe triṃśattamo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 027 999:9
#   इति स्कन्दपुराणे सप्तविंशतितमो ऽध्यायः
#   iti skandapurāṇe saptaviṃśatitamo 'dhyāyaḥ
# 032 999:9
#   इति स्कन्दपुराणे द्वात्रिंशो ऽध्यायः
#   iti skandapurāṇe dvātriṃśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 053 999:9
#   इति स्कन्दपुराणे त्रिपञ्चाशो ऽध्यायः
#   iti skandapurāṇe tripañcāśo 'dhyāyaḥ
# 054 999:9
#   इति स्कन्दपुराणे चतुष्पञ्चाशो ऽध्यायः
#   iti skandapurāṇe catuṣpañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 008 999:9
#   इति स्कन्दपुराणे अष्टमो ऽध्यायः
#   iti skandapurāṇe aṣṭamo 'dhyāyaḥ
# 060 999:9
#   इति स्कन्दपुराणे षष्टितमो ऽध्यायः
#   iti skandapurāṇe ṣaṣṭitamo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 045 999:9
#   स्कन्दपुराणे पञ्चचत्वारिंशो ऽध्यायः
#   skandapurāṇe pañcacatvāriṃśo 'dhyāyaḥ
# 047 999:9
#   स्कन्दपुराणे सप्तचत्वारिंशो ऽध्यायः
#   skandapurāṇe saptacatvāriṃśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 042 999:9
#   स्कन्दपुराणे द्वाचत्वारिंशो ऽध्यायः
#   skandapurāṇe dvācatvāriṃśo 'dhyāyaḥ
# 045 999:9
#   स्कन्दपुराणे पञ्चचत्वारिंशो ऽध्यायः
#   skandapurāṇe pañcacatvāriṃśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 012 999:9
#   इति स्कन्दपुराणे द्वादशमो ऽध्यायः
#   iti skandapurāṇe dvādaśamo 'dhyāyaḥ
# 023 999:9
#   इति स्कन्दपुराणे त्रयोविंशतिमो ऽध्यायः
#   iti skandapurāṇe trayoviṃśatimo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 023 999:9
#   इति स्कन्दपुराणे त्रयोविंशतिमो ऽध्यायः
#   iti skandapurāṇe trayoviṃśatimo 'dhyāyaḥ
# 032 999:9
#   इति स्कन्दपुराणे द्वात्रिंशो ऽध्यायः
#   iti skandapurāṇe dvātriṃśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 054 999:9
#   इति स्कन्दपुराणे चतुष्पञ्चाशो ऽध्यायः
#   iti skandapurāṇe catuṣpañcāśo 'dhyāyaḥ
# 057 999:9
#   इति स्कन्दपुराणे सप्तपञ्चाशो ऽध्यायः
#   iti skandapurāṇe saptapañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 044 999:9
#   स्कन्दपुराणे चतुश्चत्वारिंशो ऽध्यायः
#   skandapurāṇe catuścatvāriṃśo 'dhyāyaḥ
# 045 999:9
#   स्कन्दपुराणे पञ्चचत्वारिंशो ऽध्यायः
#   skandapurāṇe pañcacatvāriṃśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 022 999:9
#   इति स्कन्दपुराणे द्वाविंशतिमो ऽध्यायः
#   iti skandapurāṇe dvāviṃśatimo 'dhyāyaḥ
# 032 999:9
#   इति स्कन्दपुराणे द्वात्रिंशो ऽध्यायः
#   iti skandapurāṇe dvātriṃśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 012 999:9
#   इति स्कन्दपुराणे द्वादशमो ऽध्यायः
#   iti skandapurāṇe dvādaśamo 'dhyāyaḥ
# 027 999:9
#   इति स्कन्दपुराणे सप्तविंशतितमो ऽध्यायः
#   iti skandapurāṇe saptaviṃśatitamo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 039 999:9
#   स्कन्दपुराण एकोनचत्वारिंशत्तमो ऽध्यायः
#   skandapurāṇa ekonacatvāriṃśattamo 'dhyāyaḥ
# 041 999:9
#   स्कन्दपुराण एकचत्वारिंशो ऽध्यायः
#   skandapurāṇa ekacatvāriṃśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 052 999:9
#   इति स्कन्दपुराणे द्विपञ्चाशो ऽध्यायः
#   iti skandapurāṇe dvipañcāśo 'dhyāyaḥ
# 053 999:9
#   इति स्कन्दपुराणे त्रिपञ्चाशो ऽध्यायः
#   iti skandapurāṇe tripañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 012 999:9
#   इति स्कन्दपुराणे द्वादशमो ऽध्यायः
#   iti skandapurāṇe dvādaśamo 'dhyāyaḥ
# 020 999:9
#   इति स्कन्दपुराणे विंशतितमो ऽध्यायः
#   iti skandapurāṇe viṃśatitamo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 052 999:9
#   इति स्कन्दपुराणे द्विपञ्चाशो ऽध्यायः
#   iti skandapurāṇe dvipañcāśo 'dhyāyaḥ
# 057 999:9
#   इति स्कन्दपुराणे सप्तपञ्चाशो ऽध्यायः
#   iti skandapurāṇe saptapañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 015 999:9
#   इति स्कन्दपुराणे पञ्चदशमो ऽध्यायः
#   iti skandapurāṇe pañcadaśamo 'dhyāyaḥ
# 055 999:9
#   इति स्कन्दपुराणे पञ्चपञ्चाशो ऽध्यायः
#   iti skandapurāṇe pañcapañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 015 999:9
#   इति स्कन्दपुराणे पञ्चदशमो ऽध्यायः
#   iti skandapurāṇe pañcadaśamo 'dhyāyaḥ
# 057 999:9
#   इति स्कन्दपुराणे सप्तपञ्चाशो ऽध्यायः
#   iti skandapurāṇe saptapañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 012 999:9
#   इति स्कन्दपुराणे द्वादशमो ऽध्यायः
#   iti skandapurāṇe dvādaśamo 'dhyāyaḥ
# 022 999:9
#   इति स्कन्दपुराणे द्वाविंशतिमो ऽध्यायः
#   iti skandapurāṇe dvāviṃśatimo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 014 999:9
#   इति स्कन्दपुराणे चतुर्दशमो ऽध्यायः
#   iti skandapurāṇe caturdaśamo 'dhyāyaḥ
# 015 999:9
#   इति स्कन्दपुराणे पञ्चदशमो ऽध्यायः
#   iti skandapurāṇe pañcadaśamo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 054 999:9
#   इति स्कन्दपुराणे चतुष्पञ्चाशो ऽध्यायः
#   iti skandapurāṇe catuṣpañcāśo 'dhyāyaḥ
# 055 999:9
#   इति स्कन्दपुराणे पञ्चपञ्चाशो ऽध्यायः
#   iti skandapurāṇe pañcapañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 167S 56:2
#   तं दृष्ट्वा मनुजो व्यास राजसूयफलं लभेत्
#   taṃ dṛṣṭvā manujo vyāsa rājasūyaphalaṃ labhet
# 167S 180:2
#   तं दृष्ट्वा मनुजो भक्त्या राजसूयफलं लभेत्
#   taṃ dṛṣṭvā manujo bhaktyā rājasūyaphalaṃ labhet
#
# similarity 0.9565217391304348:
# 060 999:9
#   इति स्कन्दपुराणे षष्टितमो ऽध्यायः
#   iti skandapurāṇe ṣaṣṭitamo 'dhyāyaḥ
# 167S 999:9
#   इति स्कन्दपुराणे सप्तषष्ट्युत्तरशततमो ऽध्यायः
#   iti skandapurāṇe saptaṣaṣṭyuttaraśatatamo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 035 999:9
#   इति स्कन्दपुराणे पञ्चत्रिंशो ऽध्यायः
#   iti skandapurāṇe pañcatriṃśo 'dhyāyaḥ
# 057 999:9
#   इति स्कन्दपुराणे सप्तपञ्चाशो ऽध्यायः
#   iti skandapurāṇe saptapañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 035 999:9
#   इति स्कन्दपुराणे पञ्चत्रिंशो ऽध्यायः
#   iti skandapurāṇe pañcatriṃśo 'dhyāyaḥ
# 053 999:9
#   इति स्कन्दपुराणे त्रिपञ्चाशो ऽध्यायः
#   iti skandapurāṇe tripañcāśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 064 999:9
#   इति स्कन्दपुराणे चतुःषष्टो ऽध्यायः
#   iti skandapurāṇe catuḥṣaṣṭo 'dhyāyaḥ
# 065 999:9
#   इति स्कन्दपुराणे पञ्चषष्टो ऽध्यायः
#   iti skandapurāṇe pañcaṣaṣṭo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 040 999:9
#   स्कन्दपुराणे चत्वारिंशो ऽध्यायः
#   skandapurāṇe catvāriṃśo 'dhyāyaḥ
# 045 999:9
#   स्कन्दपुराणे पञ्चचत्वारिंशो ऽध्यायः
#   skandapurāṇe pañcacatvāriṃśo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 020 999:9
#   इति स्कन्दपुराणे विंशतितमो ऽध्यायः
#   iti skandapurāṇe viṃśatitamo 'dhyāyaḥ
# 030 999:9
#   इति स्कन्दपुराणे त्रिंशत्तमो ऽध्यायः
#   iti skandapurāṇe triṃśattamo 'dhyāyaḥ
#
# similarity 0.9565217391304348:
# 020 999:9
#   इति स्कन्दपुराणे विंशतितमो ऽध्यायः
#   iti skandapurāṇe viṃśatitamo 'dhyāyaḥ
# 032 999:9
#   इति स्कन्दपुराणे द्वात्रिंशो ऽध्यायः
#   iti skandapurāṇe dvātriṃśo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 064 999:9
#   इति स्कन्दपुराणे चतुःषष्टो ऽध्यायः
#   iti skandapurāṇe catuḥṣaṣṭo 'dhyāyaḥ
# 068 999:9
#   इति स्कन्दपुराणे ऽष्टषष्टो ऽध्यायः
#   iti skandapurāṇe 'ṣṭaṣaṣṭo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 062 999:9
#   इति स्कन्दपुराणे द्विषष्टो ऽध्यायः
#   iti skandapurāṇe dviṣaṣṭo 'dhyāyaḥ
# 068 999:9
#   इति स्कन्दपुराणे ऽष्टषष्टो ऽध्यायः
#   iti skandapurāṇe 'ṣṭaṣaṣṭo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 062 999:9
#   इति स्कन्दपुराणे द्विषष्टो ऽध्यायः
#   iti skandapurāṇe dviṣaṣṭo 'dhyāyaḥ
# 063 999:9
#   इति स्कन्दपुराणे त्रिषष्टो ऽध्यायः
#   iti skandapurāṇe triṣaṣṭo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 063 999:9
#   इति स्कन्दपुराणे त्रिषष्टो ऽध्यायः
#   iti skandapurāṇe triṣaṣṭo 'dhyāyaḥ
# 064 999:9
#   इति स्कन्दपुराणे चतुःषष्टो ऽध्यायः
#   iti skandapurāṇe catuḥṣaṣṭo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 012 999:9
#   इति स्कन्दपुराणे द्वादशमो ऽध्यायः
#   iti skandapurāṇe dvādaśamo 'dhyāyaḥ
# 013 999:9
#   इति स्कन्दपुराणे नाम त्रयोदशो ऽध्यायः
#   iti skandapurāṇe nāma trayodaśo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 010 999:9
#   इति स्कन्दपुराणे दशमो ऽध्यायः
#   iti skandapurāṇe daśamo 'dhyāyaḥ
# 014 999:9
#   इति स्कन्दपुराणे चतुर्दशमो ऽध्यायः
#   iti skandapurāṇe caturdaśamo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 062 999:9
#   इति स्कन्दपुराणे द्विषष्टो ऽध्यायः
#   iti skandapurāṇe dviṣaṣṭo 'dhyāyaḥ
# 067 999:9
#   इति स्कन्दपुराणे सप्तषष्टो ऽध्यायः
#   iti skandapurāṇe saptaṣaṣṭo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 005 19:2
#   नास्याः पुण्यतमा काचित्त्रिषु लोकेषु विद्यते
#   nāsyāḥ puṇyatamā kācittriṣu lokeṣu vidyate
# 167S 46:3
#   नातः पुण्यतमं किंचित्सर्वलोकेषु विद्यते
#   nātaḥ puṇyatamaṃ kiṃcitsarvalokeṣu vidyate
#
# similarity 0.9545454545454546:
# 062 999:9
#   इति स्कन्दपुराणे द्विषष्टो ऽध्यायः
#   iti skandapurāṇe dviṣaṣṭo 'dhyāyaḥ
# 066 999:9
#   इति स्कन्दपुराणे षट्षष्टो ऽध्यायः
#   iti skandapurāṇe ṣaṭṣaṣṭo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 064 999:9
#   इति स्कन्दपुराणे चतुःषष्टो ऽध्यायः
#   iti skandapurāṇe catuḥṣaṣṭo 'dhyāyaḥ
# 067 999:9
#   इति स्कन्दपुराणे सप्तषष्टो ऽध्यायः
#   iti skandapurāṇe saptaṣaṣṭo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 012 999:9
#   इति स्कन्दपुराणे द्वादशमो ऽध्यायः
#   iti skandapurāṇe dvādaśamo 'dhyāyaḥ
# 017 999:9
#   इति स्कन्दपुराणे सप्तदशमो ऽध्यायः
#   iti skandapurāṇe saptadaśamo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 029 999:9
#   इति स्कन्दपुराणे ऊनत्रिंशो ऽध्यायः
#   iti skandapurāṇe ūnatriṃśo 'dhyāyaḥ
# 033 999:9
#   इति स्कन्दपुराणे त्रयस्त्रिंशो ऽध्यायः
#   iti skandapurāṇe trayastriṃśo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 030 999:9
#   इति स्कन्दपुराणे त्रिंशत्तमो ऽध्यायः
#   iti skandapurāṇe triṃśattamo 'dhyāyaḥ
# 033 999:9
#   इति स्कन्दपुराणे त्रयस्त्रिंशो ऽध्यायः
#   iti skandapurāṇe trayastriṃśo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 032 999:9
#   इति स्कन्दपुराणे द्वात्रिंशो ऽध्यायः
#   iti skandapurāṇe dvātriṃśo 'dhyāyaḥ
# 033 999:9
#   इति स्कन्दपुराणे त्रयस्त्रिंशो ऽध्यायः
#   iti skandapurāṇe trayastriṃśo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 013 999:9
#   इति स्कन्दपुराणे नाम त्रयोदशो ऽध्यायः
#   iti skandapurāṇe nāma trayodaśo 'dhyāyaḥ
# 030 999:9
#   इति स्कन्दपुराणे त्रिंशत्तमो ऽध्यायः
#   iti skandapurāṇe triṃśattamo 'dhyāyaḥ
#
# similarity 0.9545454545454546:
# 167S 83:2
#   तक्षकेश्वरमित्येवं स्थापितं जाह्नवीतटे
#   takṣakeśvaramityevaṃ sthāpitaṃ jāhnavītaṭe
# 167RA4 22:2
#   तक्षेश्वरमिति ख्यातं स्थापितं जाह्नवीतटे
#   takṣeśvaramiti khyātaṃ sthāpitaṃ jāhnavītaṭe
#
# similarity 0.9545454545454546:
# 060 999:9
#   इति स्कन्दपुराणे षष्टितमो ऽध्यायः
#   iti skandapurāṇe ṣaṣṭitamo 'dhyāyaḥ
# 066 999:9
#   इति स्कन्दपुराणे षट्षष्टो ऽध्यायः
#   iti skandapurāṇe ṣaṭṣaṣṭo 'dhyāyaḥ

# %% [markdown]
# Now the second attempt, excluding lines with verse/line number 999:9.
#
# It turns out that there are less than hundred for similarity as good as 0.95.
#
# Here they are, for what it is worth.

# %%
similars = []
for (li, lj, s) in sorted(
  filterMatrix(matrixSET, 0.95),
  key=lambda x: -x[2],
):
  if (li, lj) in matrixEq: continue
  vi = L.u(li, otype='verse')[0]
  vj = L.u(lj, otype='verse')[0]
  if (
    (F.number.v(vi) == 999 and F.number.v(li) == 9)
    or
    (F.number.v(vj) == 999 and F.number.v(lj) == 9)
  ):
    continue
  if len(similars) >= 100:
    break
  similars.append((li, lj, s))
print(f'Collected {len(similars)} pairs')
# Out:
# Collected 19 pairs

# %%
for (li, lj, s) in similars: 
  print(f'similarity {s}:')
  printLine(li, caption=True)
  printLine(lj, caption=True)
  print()
# Out:
# similarity 1.0:
# 012 36:1
#   श्रुत्वा तु देवी तं नादं विप्रस्यार्तस्य शोभना
#   śrutvā tu devī taṃ nādaṃ viprasyārtasya śobhanā
# 028 1:1
#   ततो व्यास पुनर्देवी पतिं व्रतपतिं शुभा
#   tato vyāsa punardevī patiṃ vratapatiṃ śubhā
#
# similarity 1.0:
# 167S 95:1
#   अन्यदुक्तरथं नाम भवस्यायतनं शुभम्
#   anyaduktarathaṃ nāma bhavasyāyatanaṃ śubham
# 167RA5 17:1
#   अन्यद्युक्तरथं नाम भवस्यायतनं शुभम्
#   anyadyuktarathaṃ nāma bhavasyāyatanaṃ śubham
#
# similarity 1.0:
# 033 115:1
#   निवासार्थं च दिव्यं तमिन्द्रद्वीपं ददामि ते
#   nivāsārthaṃ ca divyaṃ tamindradvīpaṃ dadāmi te
# 041 17:2
#   स्वस्थानं च समासीनांस्त्रासयेद्वारयेदपि
#   svasthānaṃ ca samāsīnāṃstrāsayedvārayedapi
#
# similarity 1.0:
# 167S 105:1
#   एको राक्षसशार्दूलो यत्राद्यापि विभीषणः
#   eko rākṣasaśārdūlo yatrādyāpi vibhīṣaṇaḥ
# 167RA5 31:1
#   एत्य राक्षसशार्दूलो यत्राद्यापि विभीषणः
#   etya rākṣasaśārdūlo yatrādyāpi vibhīṣaṇaḥ
#
# similarity 0.9565217391304348:
# 167S 56:2
#   तं दृष्ट्वा मनुजो व्यास राजसूयफलं लभेत्
#   taṃ dṛṣṭvā manujo vyāsa rājasūyaphalaṃ labhet
# 167S 180:2
#   तं दृष्ट्वा मनुजो भक्त्या राजसूयफलं लभेत्
#   taṃ dṛṣṭvā manujo bhaktyā rājasūyaphalaṃ labhet
#
# similarity 0.9545454545454546:
# 005 19:2
#   नास्याः पुण्यतमा काचित्त्रिषु लोकेषु विद्यते
#   nāsyāḥ puṇyatamā kācittriṣu lokeṣu vidyate
# 167S 46:3
#   नातः पुण्यतमं किंचित्सर्वलोकेषु विद्यते
#   nātaḥ puṇyatamaṃ kiṃcitsarvalokeṣu vidyate
#
# similarity 0.9545454545454546:
# 167S 83:2
#   तक्षकेश्वरमित्येवं स्थापितं जाह्नवीतटे
#   takṣakeśvaramityevaṃ sthāpitaṃ jāhnavītaṭe
# 167RA4 22:2
#   तक्षेश्वरमिति ख्यातं स्थापितं जाह्नवीतटे
#   takṣeśvaramiti khyātaṃ sthāpitaṃ jāhnavītaṭe
#
# similarity 0.9523809523809523:
# 167S 116:2
#   द्वापरे चाषढिर्भूत्वा नृत्तेनानुगृहीतवान्
#   dvāpare cāṣaḍhirbhūtvā nṛttenānugṛhītavān
# 167RA5 50:2
#   द्वापरे चाषढिर्भूत्वा नृत्येनानुगृहीतवान्
#   dvāpare cāṣaḍhirbhūtvā nṛtyenānugṛhītavān
#
# similarity 0.9523809523809523:
# 167S 122:2
#   द्वितीयो गार्ग्य इत्येव जम्बुमार्गे सतापनः
#   dvitīyo gārgya ityeva jambumārge satāpanaḥ
# 167RA5 80:2
#   द्वितीयो गार्ग्य इत्येव जम्बुमार्गे सुतापसः
#   dvitīyo gārgya ityeva jambumārge sutāpasaḥ
#
# similarity 0.9523809523809523:
# 033 134:1
#   यो लोकदेवप्रभवेन तेन सर्वार्थसिद्धेन महाबलेन
#   yo lokadevaprabhavena tena sarvārthasiddhena mahābalena
# 167RA5 60:2
#   क्रोधलोभभयोपेता दम्भमोहान्वितास्तथा
#   krodhalobhabhayopetā dambhamohānvitāstathā
#
# similarity 0.9523809523809523:
# 167S 81:2
#   स्थानेश्वरमिति ख्यातं लोकेषु त्रिषु विश्रुतम्
#   sthāneśvaramiti khyātaṃ lokeṣu triṣu viśrutam
# 167RA4 20:3
#   स्थानेश्वरमिति ख्यातं तेन लोकेषु त्रिष्वपि
#   sthāneśvaramiti khyātaṃ tena lokeṣu triṣvapi
#
# similarity 0.95:
# 041 19:2
#   न स तं समुपैति पुण्यकर्मा विदितात्मा ह्यसिपत्रनामधेयम्
#   na sa taṃ samupaiti puṇyakarmā viditātmā hyasipatranāmadheyam
# 167S 22:2
#   महदायतनं पुण्यं सिद्धकिंनरसेवितम्
#   mahadāyatanaṃ puṇyaṃ siddhakiṃnarasevitam
#
# similarity 0.95:
# 021 57:1
#   श्रुत्वा सकृदपि ह्येतं स्तवं पापप्रणाशनम्
#   śrutvā sakṛdapi hyetaṃ stavaṃ pāpapraṇāśanam
# 034 90:2
#   तृणमप्याश्रयं कृत्वा तस्माद्वद महामुने
#   tṛṇamapyāśrayaṃ kṛtvā tasmādvada mahāmune
#
# similarity 0.95:
# 029 57:2
#   सद्यः पापविनिर्मुक्तः पशुपाशैर्विमुच्यते
#   sadyaḥ pāpavinirmuktaḥ paśupāśairvimucyate
# 050 41:2
#   श्रावयेद्वा द्विजान्सम्यक्सर्वपापैः प्रमुच्यते
#   śrāvayedvā dvijānsamyaksarvapāpaiḥ pramucyate
#
# similarity 0.95:
# 031 94:1
#   किं न वेत्सि यथा ह्येष प्रसादात्परमेश्वरात्
#   kiṃ na vetsi yathā hyeṣa prasādātparameśvarāt
# 031 115:1
#   स्थानेश्वरे यस्त्विदमेकरात्रं स्थित्वा क्षपेत्सर्वमशेषतो हि
#   sthāneśvare yastvidamekarātraṃ sthitvā kṣapetsarvamaśeṣato hi
#
# similarity 0.95:
# 031 94:1
#   किं न वेत्सि यथा ह्येष प्रसादात्परमेश्वरात्
#   kiṃ na vetsi yathā hyeṣa prasādātparameśvarāt
# 060 12:2
#   यास्यामि दक्षिणामाशां पन्थानं देहि पर्वत
#   yāsyāmi dakṣiṇāmāśāṃ panthānaṃ dehi parvata
#
# similarity 0.95:
# 005 65:2
#   गते तस्मिन्महादेवे ब्रह्मा लोकपितामहः
#   gate tasminmahādeve brahmā lokapitāmahaḥ
# 054 11:1
#   ततः स भगवान्देवो ब्रह्मा लोकपितामहः
#   tataḥ sa bhagavāndevo brahmā lokapitāmahaḥ
#
# similarity 0.95:
# 028 4:1
#   चतुर्दश्यां तथाष्टम्यामुभयोः पक्षयोः शुचिः
#   caturdaśyāṃ tathāṣṭamyāmubhayoḥ pakṣayoḥ śuciḥ
# 028 60:2
#   चतुर्दश्यामथाष्टम्यां पक्षयोरुभयोरपि
#   caturdaśyāmathāṣṭamyāṃ pakṣayorubhayorapi
#
# similarity 0.95:
# 006 6:3
#   तमुवाच ततो देवः प्रहस्य वचनं शुभम्
#   tamuvāca tato devaḥ prahasya vacanaṃ śubham
# 060 93:1
#   तस्य तद्वचनं श्रुत्वा प्रभुः प्राहासुरेश्वरम्
#   tasya tadvacanaṃ śrutvā prabhuḥ prāhāsureśvaram

# %% [markdown]
# Seeing these results, it might be a good thing to base the similarity on another measure,
# such as [edit distance](https://en.wikipedia.org/wiki/Levenshtein_distance).

# %% [markdown]
# # Working with the LCS results
#
# We follow the same exploration for the LCS method.
#
# ## Selecting the most similar lines
#
# We filter the matrix for similarities above a certain threshold.

# %% [markdown]
# How many have similarity 1?

# %%
matrix100 = filterMatrix(matrixLCS, 1)
len(matrix100)
# Out:
# 32180

# %% [markdown]
# How many of these are identical pairs?

# %%
matrixEq = {
  (li, lj)
  for (li, lj, s) in matrix100
  if lineEq(li, lj)
}

len(matrixEq)
# Out:
# 32180

# %% [markdown]
# This is the same number we got with the SET method, unsurprisingly.
#
# Our first attempt is to see what the 100 most similar
# pairs are, excluding the identical pairs.

# %%
similars = []
for (li, lj, s) in sorted(
  filterMatrix(matrixLCS, 0.95),
  key=lambda x: -x[2],
):
  if (li, lj) in matrixEq: continue
  if len(similars) >= 100:
    break
  similars.append((li, lj, s))
print(f'Collected {len(similars)} pairs')
# Out:
# Collected 15 pairs

# %%
for (li, lj, s) in similars: 
  print(f'similarity {s}:')
  printLine(li, caption=True)
  printLine(lj, caption=True)
  print()
# Out:
# similarity 0.9743589743589743:
# 167S 116:2
#   द्वापरे चाषढिर्भूत्वा नृत्तेनानुगृहीतवान्
#   dvāpare cāṣaḍhirbhūtvā nṛttenānugṛhītavān
# 167RA5 50:2
#   द्वापरे चाषढिर्भूत्वा नृत्येनानुगृहीतवान्
#   dvāpare cāṣaḍhirbhūtvā nṛtyenānugṛhītavān
#
# similarity 0.9705882352941176:
# 167S 134:1
#   आश्रमो योगिनां यत्र प्रवृत्तः पापनाशनः
#   āśramo yogināṃ yatra pravṛttaḥ pāpanāśanaḥ
# 167RA5 105:2
#   आश्रयो योगिनां यत्र प्रवृत्तः पापनाशनः
#   āśrayo yogināṃ yatra pravṛttaḥ pāpanāśanaḥ
#
# similarity 0.9705882352941176:
# 167S 136:1
#   महीनर्मदयोर्मध्यं सह्यस्य च यदुत्तरम्
#   mahīnarmadayormadhyaṃ sahyasya ca yaduttaram
# 167RA5 108:1
#   महीनर्मदयोर्मध्ये सह्यस्य च यदुत्तरम्
#   mahīnarmadayormadhye sahyasya ca yaduttaram
#
# similarity 0.96875:
# 019 999:9
#   इति स्कन्दपुराणे ऊनविंशतितमो ऽध्यायः
#   iti skandapurāṇe ūnaviṃśatitamo 'dhyāyaḥ
# 020 999:9
#   इति स्कन्दपुराणे विंशतितमो ऽध्यायः
#   iti skandapurāṇe viṃśatitamo 'dhyāyaḥ
#
# similarity 0.967741935483871:
# 167S 95:1
#   अन्यदुक्तरथं नाम भवस्यायतनं शुभम्
#   anyaduktarathaṃ nāma bhavasyāyatanaṃ śubham
# 167RA5 17:1
#   अन्यद्युक्तरथं नाम भवस्यायतनं शुभम्
#   anyadyuktarathaṃ nāma bhavasyāyatanaṃ śubham
#
# similarity 0.967741935483871:
# 009 14:1
#   यदि तुष्टो ऽसि देवेश यदि देयो वरश्च नः
#   yadi tuṣṭo 'si deveśa yadi deyo varaśca naḥ
# 033 23:1
#   यदि तुष्टो ऽसि देवेश यदि देयो वरश्च नौ
#   yadi tuṣṭo 'si deveśa yadi deyo varaśca nau
#
# similarity 0.9655172413793104:
# 005 999:9
#   इति स्कन्दपुराणे पञ्चमो ऽध्यायः
#   iti skandapurāṇe pañcamo 'dhyāyaḥ
# 015 999:9
#   इति स्कन्दपुराणे पञ्चदशमो ऽध्यायः
#   iti skandapurāṇe pañcadaśamo 'dhyāyaḥ
#
# similarity 0.9655172413793104:
# 007 999:9
#   इति स्कन्दपुराणे सप्तमो ऽध्यायः
#   iti skandapurāṇe saptamo 'dhyāyaḥ
# 017 999:9
#   इति स्कन्दपुराणे सप्तदशमो ऽध्यायः
#   iti skandapurāṇe saptadaśamo 'dhyāyaḥ
#
# similarity 0.961038961038961:
# 167S 122:2
#   द्वितीयो गार्ग्य इत्येव जम्बुमार्गे सतापनः
#   dvitīyo gārgya ityeva jambumārge satāpanaḥ
# 167RA5 80:2
#   द्वितीयो गार्ग्य इत्येव जम्बुमार्गे सुतापसः
#   dvitīyo gārgya ityeva jambumārge sutāpasaḥ
#
# similarity 0.9577464788732394:
# 167S 69:1
#   कुम्भकारेश्वरे चैव तथैवोत्कुटुकेश्वरे
#   kumbhakāreśvare caiva tathaivotkuṭukeśvare
# 167RA3 27:1
#   कुम्भकर्णेश्वरे चैव तथैवोत्कुटुकेश्वरे
#   kumbhakarṇeśvare caiva tathaivotkuṭukeśvare
#
# similarity 0.9552238805970149:
# 036 999:9
#   स्कन्दपुराणे षट्त्रिंशत्तमो ऽध्यायः
#   skandapurāṇe ṣaṭtriṃśattamo 'dhyāyaḥ
# 038 999:9
#   स्कन्दपुराणे ऽष्टत्रिंशत्तमो ऽध्यायः
#   skandapurāṇe 'ṣṭatriṃśattamo 'dhyāyaḥ
#
# similarity 0.9538461538461539:
# 046 999:9
#   स्कन्दपुराणे षट्चत्वारिंशो ऽध्यायः
#   skandapurāṇe ṣaṭcatvāriṃśo 'dhyāyaḥ
# 048 999:9
#   स्कन्दपुराणे ऽष्टचत्वारिंशो ऽध्यायः
#   skandapurāṇe 'ṣṭacatvāriṃśo 'dhyāyaḥ
#
# similarity 0.9523809523809523:
# 037 999:9
#   स्कन्दपुराणे सप्तत्रिंशो ऽध्यायः
#   skandapurāṇe saptatriṃśo 'dhyāyaḥ
# 047 999:9
#   स्कन्दपुराणे सप्तचत्वारिंशो ऽध्यायः
#   skandapurāṇe saptacatvāriṃśo 'dhyāyaḥ
#
# similarity 0.9508196721311475:
# 040 999:9
#   स्कन्दपुराणे चत्वारिंशो ऽध्यायः
#   skandapurāṇe catvāriṃśo 'dhyāyaḥ
# 046 999:9
#   स्कन्दपुराणे षट्चत्वारिंशो ऽध्यायः
#   skandapurāṇe ṣaṭcatvāriṃśo 'dhyāyaḥ
#
# similarity 0.9508196721311475:
# 066 999:9
#   इति स्कन्दपुराणे षट्षष्टो ऽध्यायः
#   iti skandapurāṇe ṣaṭṣaṣṭo 'dhyāyaḥ
# 068 999:9
#   इति स्कन्दपुराणे ऽष्टषष्टो ऽध्यायः
#   iti skandapurāṇe 'ṣṭaṣaṣṭo 'dhyāyaḥ

# %% [markdown]
# There are not many pairs that have such a high similarity, and we do see the 999:9 lines.
#
# In our second attempt, we exclude lines with verse/line number 999:9, and we lower the required
# similarity to 0.8.
#
# It also appears that there are a lot of similarities between lines with a single word.
# We also skip them.
#
# Let's see what we get.

# %%
similars = []
for (li, lj, s) in sorted(
  filterMatrix(matrixLCS, 0.8),
  key=lambda x: -x[2],
):
  if (li, lj) in matrixEq: continue
  vi = L.u(li, otype='verse')[0]
  vj = L.u(lj, otype='verse')[0]
  if (
    (F.number.v(vi) == 999 and F.number.v(li) == 9)
    or
    (F.number.v(vj) == 999 and F.number.v(lj) == 9)
  ):
    continue
  if len(devText(li).split()) == 1 and len(devText(lj).split()) == 1:
    continue
  if len(similars) >= 100:
    break
  similars.append((li, lj, s))
print(f'Collected {len(similars)} pairs')
# Out:
# Collected 87 pairs

# %%
for (li, lj, s) in similars: 
  print(f'similarity {s}:')
  printLine(li, caption=True)
  printLine(lj, caption=True)
  print()
# Out:
# similarity 0.9743589743589743:
# 167S 116:2
#   द्वापरे चाषढिर्भूत्वा नृत्तेनानुगृहीतवान्
#   dvāpare cāṣaḍhirbhūtvā nṛttenānugṛhītavān
# 167RA5 50:2
#   द्वापरे चाषढिर्भूत्वा नृत्येनानुगृहीतवान्
#   dvāpare cāṣaḍhirbhūtvā nṛtyenānugṛhītavān
#
# similarity 0.9705882352941176:
# 167S 134:1
#   आश्रमो योगिनां यत्र प्रवृत्तः पापनाशनः
#   āśramo yogināṃ yatra pravṛttaḥ pāpanāśanaḥ
# 167RA5 105:2
#   आश्रयो योगिनां यत्र प्रवृत्तः पापनाशनः
#   āśrayo yogināṃ yatra pravṛttaḥ pāpanāśanaḥ
#
# similarity 0.9705882352941176:
# 167S 136:1
#   महीनर्मदयोर्मध्यं सह्यस्य च यदुत्तरम्
#   mahīnarmadayormadhyaṃ sahyasya ca yaduttaram
# 167RA5 108:1
#   महीनर्मदयोर्मध्ये सह्यस्य च यदुत्तरम्
#   mahīnarmadayormadhye sahyasya ca yaduttaram
#
# similarity 0.967741935483871:
# 167S 95:1
#   अन्यदुक्तरथं नाम भवस्यायतनं शुभम्
#   anyaduktarathaṃ nāma bhavasyāyatanaṃ śubham
# 167RA5 17:1
#   अन्यद्युक्तरथं नाम भवस्यायतनं शुभम्
#   anyadyuktarathaṃ nāma bhavasyāyatanaṃ śubham
#
# similarity 0.967741935483871:
# 009 14:1
#   यदि तुष्टो ऽसि देवेश यदि देयो वरश्च नः
#   yadi tuṣṭo 'si deveśa yadi deyo varaśca naḥ
# 033 23:1
#   यदि तुष्टो ऽसि देवेश यदि देयो वरश्च नौ
#   yadi tuṣṭo 'si deveśa yadi deyo varaśca nau
#
# similarity 0.961038961038961:
# 167S 122:2
#   द्वितीयो गार्ग्य इत्येव जम्बुमार्गे सतापनः
#   dvitīyo gārgya ityeva jambumārge satāpanaḥ
# 167RA5 80:2
#   द्वितीयो गार्ग्य इत्येव जम्बुमार्गे सुतापसः
#   dvitīyo gārgya ityeva jambumārge sutāpasaḥ
#
# similarity 0.9577464788732394:
# 167S 69:1
#   कुम्भकारेश्वरे चैव तथैवोत्कुटुकेश्वरे
#   kumbhakāreśvare caiva tathaivotkuṭukeśvare
# 167RA3 27:1
#   कुम्भकर्णेश्वरे चैव तथैवोत्कुटुकेश्वरे
#   kumbhakarṇeśvare caiva tathaivotkuṭukeśvare
#
# similarity 0.9411764705882353:
# 036 26:1
#   अत्र ते वर्तयिष्यामः पुरावृत्तं महामते
#   atra te vartayiṣyāmaḥ purāvṛttaṃ mahāmate
# 057 83:1
#   अत्र ते वर्तयिष्यामि पुरावृत्तं महातपे
#   atra te vartayiṣyāmi purāvṛttaṃ mahātape
#
# similarity 0.9315068493150684:
# 167S 51:1
#   तद्गौरीशिखरं पुण्यं ये ऽभिगच्छन्ति मानवाः
#   tadgaurīśikharaṃ puṇyaṃ ye 'bhigacchanti mānavāḥ
# 167RA2 15:1
#   तद्गौरीशिखरं रम्यं ये ऽभिगच्छन्ति मानवाः
#   tadgaurīśikharaṃ ramyaṃ ye 'bhigacchanti mānavāḥ
#
# similarity 0.9295774647887324:
# 167S 105:1
#   एको राक्षसशार्दूलो यत्राद्यापि विभीषणः
#   eko rākṣasaśārdūlo yatrādyāpi vibhīṣaṇaḥ
# 167RA5 31:1
#   एत्य राक्षसशार्दूलो यत्राद्यापि विभीषणः
#   etya rākṣasaśārdūlo yatrādyāpi vibhīṣaṇaḥ
#
# similarity 0.9259259259259259:
# 167S 66:3
#   महाभैरव इत्येव तदायतनमुच्यते
#   mahābhairava ityeva tadāyatanamucyate
# 167RA3 23:1
#   महाभैरवमित्येवं तदायतनमुच्यते
#   mahābhairavamityevaṃ tadāyatanamucyate
#
# similarity 0.9253731343283582:
# 167S 72:2
#   देवदारुवनैश्छन्नं सरलैश्च सुगन्धिभिः
#   devadāruvanaiśchannaṃ saralaiśca sugandhibhiḥ
# 167RA3 36:2
#   देवदारुवनैश्छन्नं सरलैश्च सुगन्धकैः
#   devadāruvanaiśchannaṃ saralaiśca sugandhakaiḥ
#
# similarity 0.9142857142857143:
# 167S 56:2
#   तं दृष्ट्वा मनुजो व्यास राजसूयफलं लभेत्
#   taṃ dṛṣṭvā manujo vyāsa rājasūyaphalaṃ labhet
# 167S 180:2
#   तं दृष्ट्वा मनुजो भक्त्या राजसूयफलं लभेत्
#   taṃ dṛṣṭvā manujo bhaktyā rājasūyaphalaṃ labhet
#
# similarity 0.9142857142857143:
# 167S 58:2
#   मानुषाणामशीलत्वात्संवृत्ता दारवो बभुः
#   mānuṣāṇāmaśīlatvātsaṃvṛttā dāravo babhuḥ
# 167RA2 59:2
#   मानुषाणामशीलत्वात्संवृत्ता दारवः पुनः
#   mānuṣāṇāmaśīlatvātsaṃvṛttā dāravaḥ punaḥ
#
# similarity 0.9122807017543859:
# 167S 72:1
#   देवदारुवने चापि भवस्यायतनं वरम्
#   devadāruvane cāpi bhavasyāyatanaṃ varam
# 167RA3 36:1
#   देवदारुवने चापि भवस्यायतनं शुभम्
#   devadāruvane cāpi bhavasyāyatanaṃ śubham
#
# similarity 0.9122807017543859:
# 015 19:1
#   नमः कनकलिङ्गाय वेदलिङ्गाय वै नमः
#   namaḥ kanakaliṅgāya vedaliṅgāya vai namaḥ
# 021 22:2
#   नमः कनकलिङ्गाय सर्वलिङ्गाय वै नमः
#   namaḥ kanakaliṅgāya sarvaliṅgāya vai namaḥ
#
# similarity 0.9117647058823529:
# 167S 131:1
#   नदीतीरेषु मेध्येषु पुण्येष्वायतनेषु च
#   nadītīreṣu medhyeṣu puṇyeṣvāyataneṣu ca
# 167RA5 98:1
#   नदीतीरेषु मेध्येषु मेध्येष्वायतनेषु च
#   nadītīreṣu medhyeṣu medhyeṣvāyataneṣu ca
#
# similarity 0.9117647058823529:
# 032 191:2
#   सर्वपापविनिर्मुक्तः शक्रलोके महीयते
#   sarvapāpavinirmuktaḥ śakraloke mahīyate
# 032 202:2
#   सर्वपापविनिर्मुक्तः स्वर्गलोके महीयते
#   sarvapāpavinirmuktaḥ svargaloke mahīyate
#
# similarity 0.9041095890410958:
# 167S 83:2
#   तक्षकेश्वरमित्येवं स्थापितं जाह्नवीतटे
#   takṣakeśvaramityevaṃ sthāpitaṃ jāhnavītaṭe
# 167RA4 22:2
#   तक्षेश्वरमिति ख्यातं स्थापितं जाह्नवीतटे
#   takṣeśvaramiti khyātaṃ sthāpitaṃ jāhnavītaṭe
#
# similarity 0.9041095890410958:
# 167RA2 22:2
#   यत्र भस्त्रेश्वरं नाम रुद्रस्यायतनं शुभम्
#   yatra bhastreśvaraṃ nāma rudrasyāyatanaṃ śubham
# 167RA2 23:1
#   कथं भस्त्रेश्वरं नाम रुद्रस्यायतनं शुभम्
#   kathaṃ bhastreśvaraṃ nāma rudrasyāyatanaṃ śubham
#
# similarity 0.9041095890410958:
# 167S 54:2
#   यत्र भस्त्रेश्वरं नाम रुद्रस्यायतनं शुभम्
#   yatra bhastreśvaraṃ nāma rudrasyāyatanaṃ śubham
# 167RA2 23:1
#   कथं भस्त्रेश्वरं नाम रुद्रस्यायतनं शुभम्
#   kathaṃ bhastreśvaraṃ nāma rudrasyāyatanaṃ śubham
#
# similarity 0.9014084507042254:
# 167S 128:2
#   जम्बूमार्गे द्वितीयं च मथुरायां ततो ऽपरम्
#   jambūmārge dvitīyaṃ ca mathurāyāṃ tato 'param
# 167RA5 86:2
#   जम्बुमार्गे द्वितीयं च मथुरायां तथापरम्
#   jambumārge dvitīyaṃ ca mathurāyāṃ tathāparam
#
# similarity 0.8955223880597015:
# 007 3:1
#   तस्य तुष्टस्तदा देवो वरदो ऽस्मीत्यभाषत
#   tasya tuṣṭastadā devo varado 'smītyabhāṣata
# 016 4:2
#   तस्य तुष्टो महादेवो वरदो ऽस्मीत्यभाषत
#   tasya tuṣṭo mahādevo varado 'smītyabhāṣata
#
# similarity 0.8888888888888888:
# 167S 15:1
#   तस्मिन्नायतने रुद्रं तृणाङ्गः स महानृषिः
#   tasminnāyatane rudraṃ tṛṇāṅgaḥ sa mahānṛṣiḥ
# 167RA1 30:1
#   तस्मिन्नायतने दिव्ये तृणाङ्गः स महानृषिः
#   tasminnāyatane divye tṛṇāṅgaḥ sa mahānṛṣiḥ
#
# similarity 0.8767123287671232:
# 050 9:1
#   तृतीये त्वथ ये प्रोक्ता मया दुष्कृतकारिणः
#   tṛtīye tvatha ye proktā mayā duṣkṛtakāriṇaḥ
# 050 11:1
#   चतुर्थे त्वथ ये प्रोक्ता मया दुष्कृतकारिणः
#   caturthe tvatha ye proktā mayā duṣkṛtakāriṇaḥ
#
# similarity 0.8709677419354839:
# 033 23:1
#   यदि तुष्टो ऽसि देवेश यदि देयो वरश्च नौ
#   yadi tuṣṭo 'si deveśa yadi deyo varaśca nau
# 034 13:1
#   यदि तुष्टो ऽसि मे देव यदि देयो वरश्च मे
#   yadi tuṣṭo 'si me deva yadi deyo varaśca me
#
# similarity 0.8709677419354839:
# 009 14:1
#   यदि तुष्टो ऽसि देवेश यदि देयो वरश्च नः
#   yadi tuṣṭo 'si deveśa yadi deyo varaśca naḥ
# 034 13:1
#   यदि तुष्टो ऽसि मे देव यदि देयो वरश्च मे
#   yadi tuṣṭo 'si me deva yadi deyo varaśca me
#
# similarity 0.8666666666666667:
# 167S 126:2
#   जगामोज्जयनीं देवः श्मशानं च विवेश ह
#   jagāmojjayanīṃ devaḥ śmaśānaṃ ca viveśa ha
# 167RA5 84:2
#   जगामोज्जयनीं तत्र श्मशानं च विवेश ह
#   jagāmojjayanīṃ tatra śmaśānaṃ ca viveśa ha
#
# similarity 0.8656716417910447:
# 003 3:1
#   इदं पुत्राय शिष्याय धार्मिकायानसूयवे
#   idaṃ putrāya śiṣyāya dhārmikāyānasūyave
# 033 133:1
#   इदं पुत्राय शिष्याय धार्मिकाय महात्मने
#   idaṃ putrāya śiṣyāya dhārmikāya mahātmane
#
# similarity 0.8611111111111112:
# 005 65:1
#   इत्युक्त्वा देवदेवेशस्तत्रैवान्तरधीयत
#   ityuktvā devadeveśastatraivāntaradhīyata
# 034 92:2
#   इत्युक्त्वा तं महादेवस्तत्रैवान्तरधीयत
#   ityuktvā taṃ mahādevastatraivāntaradhīyata
#
# similarity 0.8611111111111112:
# 167S 70:1
#   रुद्रकोटीति चाप्यन्यच्छिवायतनमुच्यते
#   rudrakoṭīti cāpyanyacchivāyatanamucyate
# 167RA3 29:1
#   रुद्रकोटीति चाप्यन्यद्रुद्रायतनमुच्यते
#   rudrakoṭīti cāpyanyadrudrāyatanamucyate
#
# similarity 0.8533333333333334:
# 167S 117:1
#   एवं प्रतियुगं व्यास तस्मिन्देशे शिवः स्वयम्
#   evaṃ pratiyugaṃ vyāsa tasmindeśe śivaḥ svayam
# 167RA5 51:1
#   एवं युगे युगे व्यास तस्मिन्देशे शिवः स्वयम्
#   evaṃ yuge yuge vyāsa tasmindeśe śivaḥ svayam
#
# similarity 0.8484848484848485:
# 022 5:1
#   अमरो जरया त्यक्तो नित्यं दुःखविवर्जितः
#   amaro jarayā tyakto nityaṃ duḥkhavivarjitaḥ
# 034 110:1
#   अमरो जरया त्यक्तः सर्वदुःखविवर्जितः
#   amaro jarayā tyaktaḥ sarvaduḥkhavivarjitaḥ
#
# similarity 0.8484848484848485:
# 022 5:1
#   अमरो जरया त्यक्तो नित्यं दुःखविवर्जितः
#   amaro jarayā tyakto nityaṃ duḥkhavivarjitaḥ
# 069 39:1
#   अमरो जरया त्यक्तः सर्वदुःखविवर्जितः
#   amaro jarayā tyaktaḥ sarvaduḥkhavivarjitaḥ
#
# similarity 0.8484848484848485:
# 005 67:2
#   स सर्वपापनिर्मुक्तो रुद्रलोके महीयते
#   sa sarvapāpanirmukto rudraloke mahīyate
# 032 191:2
#   सर्वपापविनिर्मुक्तः शक्रलोके महीयते
#   sarvapāpavinirmuktaḥ śakraloke mahīyate
#
# similarity 0.8484848484848485:
# 022 5:1
#   अमरो जरया त्यक्तो नित्यं दुःखविवर्जितः
#   amaro jarayā tyakto nityaṃ duḥkhavivarjitaḥ
# 035 26:1
#   अमरो जरया त्यक्तः सर्वदुःखविवर्जितः
#   amaro jarayā tyaktaḥ sarvaduḥkhavivarjitaḥ
#
# similarity 0.847457627118644:
# 033 129:1
#   एवं स भगवान्देवः परमैश्वर्यसंयुतः
#   evaṃ sa bhagavāndevaḥ paramaiśvaryasaṃyutaḥ
# 167S 124:1
#   भगवानपि देवेशः परमैश्वर्यसंयुतः
#   bhagavānapi deveśaḥ paramaiśvaryasaṃyutaḥ
#
# similarity 0.847457627118644:
# 033 129:1
#   एवं स भगवान्देवः परमैश्वर्यसंयुतः
#   evaṃ sa bhagavāndevaḥ paramaiśvaryasaṃyutaḥ
# 167RA5 82:1
#   भगवानपि देवेशः परमैश्वर्यसंयुतः
#   bhagavānapi deveśaḥ paramaiśvaryasaṃyutaḥ
#
# similarity 0.8470588235294118:
# 167S 109:1
#   हरिश्चन्द्रगिरेः शृङ्गमाकूटं यैर्निरीक्षितम्
#   hariścandragireḥ śṛṅgamākūṭaṃ yairnirīkṣitam
# 167RA5 38:1
#   हरिश्चन्द्रस्य तच्छृङ्गमाकूटं यैर्निरीक्षितम्
#   hariścandrasya tacchṛṅgamākūṭaṃ yairnirīkṣitam
#
# similarity 0.8461538461538461:
# 005 50:1
#   नमः सहस्रलिङ्गाय सहस्रचरणाय च
#   namaḥ sahasraliṅgāya sahasracaraṇāya ca
# 014 5:1
#   नमः सहस्रनेत्राय सहस्रचरणाय च
#   namaḥ sahasranetrāya sahasracaraṇāya ca
#
# similarity 0.8461538461538461:
# 010 40:3
#   सर्वपापविनिर्मुक्तो रुद्रलोकमवाप्नुयात्
#   sarvapāpavinirmukto rudralokamavāpnuyāt
# 167S 53:2
#   दृष्ट्वा पापविनिर्मुक्तो रुद्रलोकमवाप्नुते
#   dṛṣṭvā pāpavinirmukto rudralokamavāpnute
#
# similarity 0.8461538461538461:
# 031 108:2
#   सर्वपापविनिर्मुक्तो रुद्रलोकमवाप्नुयात्
#   sarvapāpavinirmukto rudralokamavāpnuyāt
# 167S 53:2
#   दृष्ट्वा पापविनिर्मुक्तो रुद्रलोकमवाप्नुते
#   dṛṣṭvā pāpavinirmukto rudralokamavāpnute
#
# similarity 0.84375:
# 026 24:1
#   स एवमुक्तस्तेजस्वी निकुम्भो गणसत्तमः
#   sa evamuktastejasvī nikumbho gaṇasattamaḥ
# 036 52:1
#   स एवमुक्तस्तेजस्वी सुकेशो गणसत्तमः
#   sa evamuktastejasvī sukeśo gaṇasattamaḥ
#
# similarity 0.8433734939759037:
# 167S 53:2
#   दृष्ट्वा पापविनिर्मुक्तो रुद्रलोकमवाप्नुते
#   dṛṣṭvā pāpavinirmukto rudralokamavāpnute
# 167S 164:2
#   दृष्ट्वा पापविनिर्मुक्तः स्वर्गलोकमवाप्नुयात्
#   dṛṣṭvā pāpavinirmuktaḥ svargalokamavāpnuyāt
#
# similarity 0.8421052631578947:
# 031 29:0
#   मन्दर उवाच
#   mandara uvāca
# 031 54:0
#   इन्द्र उवाच
#   indra uvāca
#
# similarity 0.8421052631578947:
# 167S 92:1
#   अन्ध्रेष्वायतनं चान्यच्छर्वस्य परमात्मनः
#   andhreṣvāyatanaṃ cānyaccharvasya paramātmanaḥ
# 167RA5 12:1
#   अन्ध्रेष्वायतनं चास्ति रुद्रस्य परमात्मनः
#   andhreṣvāyatanaṃ cāsti rudrasya paramātmanaḥ
#
# similarity 0.8421052631578947:
# 023 41:1
#   ततो ऽपरः सहस्रेण कोटीनां गणपो वृतः
#   tato 'paraḥ sahasreṇa koṭīnāṃ gaṇapo vṛtaḥ
# 023 49:2
#   महारवः सहस्रेण कोटीनां गणपो वृतः
#   mahāravaḥ sahasreṇa koṭīnāṃ gaṇapo vṛtaḥ
#
# similarity 0.8387096774193549:
# 031 101:1
#   भगवन्यदि तुष्टो ऽसि यदि देयो वरश्च मे
#   bhagavanyadi tuṣṭo 'si yadi deyo varaśca me
# 034 13:1
#   यदि तुष्टो ऽसि मे देव यदि देयो वरश्च मे
#   yadi tuṣṭo 'si me deva yadi deyo varaśca me
#
# similarity 0.8387096774193549:
# 020 24:1
#   भगवन्यदि तुष्टो ऽसि यदि देयो वरश्च मे
#   bhagavanyadi tuṣṭo 'si yadi deyo varaśca me
# 034 13:1
#   यदि तुष्टो ऽसि मे देव यदि देयो वरश्च मे
#   yadi tuṣṭo 'si me deva yadi deyo varaśca me
#
# similarity 0.8387096774193549:
# 167S 58:1
#   वृक्षाः कनखला नाम यत्रासन्कनकात्मकाः
#   vṛkṣāḥ kanakhalā nāma yatrāsankanakātmakāḥ
# 167RA2 59:1
#   वृक्षाः कनखला नाम यत्र ते कनकामयाः
#   vṛkṣāḥ kanakhalā nāma yatra te kanakāmayāḥ
#
# similarity 0.8378378378378378:
# 167S 68:1
#   यदेवाश्रमिणां पुण्यं तथैशव्रतचारिणाम्
#   yadevāśramiṇāṃ puṇyaṃ tathaiśavratacāriṇām
# 167RA3 26:1
#   यच्चेहाश्रमिणां पुण्यं तथैव ब्रह्मचारिणाम्
#   yaccehāśramiṇāṃ puṇyaṃ tathaiva brahmacāriṇām
#
# similarity 0.8378378378378378:
# 167S 106:1
#   मानवा ये ऽभिगच्छन्ति गोकर्णायतनाश्रमम्
#   mānavā ye 'bhigacchanti gokarṇāyatanāśramam
# 167RA5 32:1
#   मर्त्या ये त्वभिगच्छन्ति गोकर्णायतनाश्रमम्
#   martyā ye tvabhigacchanti gokarṇāyatanāśramam
#
# similarity 0.835820895522388:
# 167S 104:2
#   स्पृक्कया जातया यत्र लङ्कामलयसानुषु
#   spṛkkayā jātayā yatra laṅkāmalayasānuṣu
# 167RA5 30:1
#   स्पृक्कया जातया तत्र लङ्कासु मलयाद्रिषु
#   spṛkkayā jātayā tatra laṅkāsu malayādriṣu
#
# similarity 0.835820895522388:
# 060 72:2
#   तत्र चेरतुरत्युग्रं तपो ऽम्बुपवनाशनौ
#   tatra ceraturatyugraṃ tapo 'mbupavanāśanau
# 062 55:2
#   तपश्चेरतुरत्युग्रं पर्णाम्बुपवनाशनौ
#   tapaśceraturatyugraṃ parṇāmbupavanāśanau
#
# similarity 0.8354430379746836:
# 167S 81:2
#   स्थानेश्वरमिति ख्यातं लोकेषु त्रिषु विश्रुतम्
#   sthāneśvaramiti khyātaṃ lokeṣu triṣu viśrutam
# 167RA4 20:3
#   स्थानेश्वरमिति ख्यातं तेन लोकेषु त्रिष्वपि
#   sthāneśvaramiti khyātaṃ tena lokeṣu triṣvapi
#
# similarity 0.8333333333333334:
# 015 20:2
#   नमः पवनलिङ्गाय ब्रह्मलिङ्गाय वै नमः
#   namaḥ pavanaliṅgāya brahmaliṅgāya vai namaḥ
# 021 22:2
#   नमः कनकलिङ्गाय सर्वलिङ्गाय वै नमः
#   namaḥ kanakaliṅgāya sarvaliṅgāya vai namaḥ
#
# similarity 0.8333333333333334:
# 167S 124:2
#   अत्रिवंशप्रसूतस्य नाम्ना वै सोमशर्मणः
#   atrivaṃśaprasūtasya nāmnā vai somaśarmaṇaḥ
# 167RA5 82:2
#   अत्रेर्वंशप्रसूतस्य नाम्ना वै वृद्धशर्मणः
#   atrervaṃśaprasūtasya nāmnā vai vṛddhaśarmaṇaḥ
#
# similarity 0.8333333333333334:
# 167S 62:2
#   यत्र जप्यं पुरा कृत्वा लिङ्गं स्थापितवान्द्विजः
#   yatra japyaṃ purā kṛtvā liṅgaṃ sthāpitavāndvijaḥ
# 167RA3 1:2
#   यत्र नन्दिर्जपं कृत्वा लिङ्गं स्थापितवान्द्विज
#   yatra nandirjapaṃ kṛtvā liṅgaṃ sthāpitavāndvija
#
# similarity 0.8285714285714286:
# 167S 96:1
#   तत्र श्रीपर्वतं नाम पर्वतः श्रीनिकेतनः
#   tatra śrīparvataṃ nāma parvataḥ śrīniketanaḥ
# 167RA5 21:1
#   अन्यच्छ्रीपर्वतो नाम पर्वतः श्रीनिकेतनः
#   anyacchrīparvato nāma parvataḥ śrīniketanaḥ
#
# similarity 0.8266666666666667:
# 030 51:2
#   ब्रह्मादयो विजानन्ति ये च सिद्धा मुमुक्षवः
#   brahmādayo vijānanti ye ca siddhā mumukṣavaḥ
# 167S 77:1
#   ब्रह्मादयस्ततो देवास्ते च सिद्धा मुमुक्षवः
#   brahmādayastato devāste ca siddhā mumukṣavaḥ
#
# similarity 0.8253968253968254:
# 041 1:1
#   अतः परं प्रवक्ष्यामि असिपत्रवनं पुनः
#   ataḥ paraṃ pravakṣyāmi asipatravanaṃ punaḥ
# 046 1:1
#   अतः परं प्रवक्ष्यामि रौरवं नरकं पुनः
#   ataḥ paraṃ pravakṣyāmi rauravaṃ narakaṃ punaḥ
#
# similarity 0.8253968253968254:
# 167S 89:2
#   स्थापितं तोषयानेन सर्वभूतपतिं भवम्
#   sthāpitaṃ toṣayānena sarvabhūtapatiṃ bhavam
# 167RA5 9:2
#   स्थापितं तोषयामास सर्वभूतपतिं पतिम्
#   sthāpitaṃ toṣayāmāsa sarvabhūtapatiṃ patim
#
# similarity 0.8235294117647058:
# 031 68:0
#   क्षुप उवाच
#   kṣupa uvāca
# 032 171:0
#   दक्ष उवाच
#   dakṣa uvāca
#
# similarity 0.8235294117647058:
# 037 58:1
#   एवं स यात्यमानो वै बहूनब्दान्सुदुःखितः
#   evaṃ sa yātyamāno vai bahūnabdānsuduḥkhitaḥ
# 046 7:1
#   एवं स यात्यते तत्र बहूनब्दान्सुदुःखितः
#   evaṃ sa yātyate tatra bahūnabdānsuduḥkhitaḥ
#
# similarity 0.8235294117647058:
# 031 68:0
#   क्षुप उवाच
#   kṣupa uvāca
# 032 187:0
#   दक्ष उवाच
#   dakṣa uvāca
#
# similarity 0.8235294117647058:
# 005 67:2
#   स सर्वपापनिर्मुक्तो रुद्रलोके महीयते
#   sa sarvapāpanirmukto rudraloke mahīyate
# 032 202:2
#   सर्वपापविनिर्मुक्तः स्वर्गलोके महीयते
#   sarvapāpavinirmuktaḥ svargaloke mahīyate
#
# similarity 0.819672131147541:
# 167S 94:2
#   तच्चित्ररथमासाद्य फलं लभति मानवः
#   taccitrarathamāsādya phalaṃ labhati mānavaḥ
# 167RA5 15:2
#   तच्चित्ररथमासाद्य फलं भवति शाश्वतम्
#   taccitrarathamāsādya phalaṃ bhavati śāśvatam
#
# similarity 0.819672131147541:
# 016 10:2
#   बीजात्मना न भवति परिणामान्तरं गतः
#   bījātmanā na bhavati pariṇāmāntaraṃ gataḥ
# 016 11:2
#   स्वेनात्मना न भविता परिणामान्तरं गतः
#   svenātmanā na bhavitā pariṇāmāntaraṃ gataḥ
#
# similarity 0.8181818181818182:
# 015 20:1
#   नमः पुराणलिङ्गाय श्रुतिलिङ्गाय वै नमः
#   namaḥ purāṇaliṅgāya śrutiliṅgāya vai namaḥ
# 015 21:2
#   नमः पर्वतलिङ्गाय स्थितिलिङ्गाय वै नमः
#   namaḥ parvataliṅgāya sthitiliṅgāya vai namaḥ
#
# similarity 0.8181818181818182:
# 167S 11:2
#   धारयन्ति महात्मान आशीर्भिः सरथं रविम्
#   dhārayanti mahātmāna āśīrbhiḥ sarathaṃ ravim
# 167RA1 23:2
#   धारयन्ति धृताचारा आशीर्भिः सरथं रविम्
#   dhārayanti dhṛtācārā āśīrbhiḥ sarathaṃ ravim
#
# similarity 0.8181818181818182:
# 029 165:1
#   य इमं पठते नित्यं स्तवं प्रातः समुत्थितः
#   ya imaṃ paṭhate nityaṃ stavaṃ prātaḥ samutthitaḥ
# 032 64:1
#   य इमं पठते नित्यं नियतः प्रातरुत्थितः
#   ya imaṃ paṭhate nityaṃ niyataḥ prātarutthitaḥ
#
# similarity 0.813953488372093:
# 037 52:2
#   तत्र तैः कण्टकैस्तीक्ष्णैर्भिद्यते पक्षिभिश्च ह
#   tatra taiḥ kaṇṭakaistīkṣṇairbhidyate pakṣibhiśca ha
# 038 12:2
#   तत्र तैः कण्टकैस्तीक्ष्णैर्भिद्यते छिद्यते ऽपि च
#   tatra taiḥ kaṇṭakaistīkṣṇairbhidyate chidyate 'pi ca
#
# similarity 0.813953488372093:
# 032 137:2
#   श्रावयेच्चापि द्विजेभ्यः सर्वपापैः प्रमुच्यते
#   śrāvayeccāpi dvijebhyaḥ sarvapāpaiḥ pramucyate
# 050 41:2
#   श्रावयेद्वा द्विजान्सम्यक्सर्वपापैः प्रमुच्यते
#   śrāvayedvā dvijānsamyaksarvapāpaiḥ pramucyate
#
# similarity 0.8135593220338984:
# 021 49:3
#   नमस्ते सर्वलोकेश नमस्ते लोकभावन
#   namaste sarvalokeśa namaste lokabhāvana
# 029 209:2
#   नमस्ते सर्वदेवत्यै नमस्ते लोकभावनि
#   namaste sarvadevatyai namaste lokabhāvani
#
# similarity 0.8135593220338984:
# 029 209:2
#   नमस्ते सर्वदेवत्यै नमस्ते लोकभावनि
#   namaste sarvadevatyai namaste lokabhāvani
# 032 63:1
#   नमस्ते सर्वलोकेश नमस्ते लोकभावन
#   namaste sarvalokeśa namaste lokabhāvana
#
# similarity 0.8125:
# 038 1:1
#   अतः परं प्रवक्ष्यामि शाल्मलीनरकं पुनः
#   ataḥ paraṃ pravakṣyāmi śālmalīnarakaṃ punaḥ
# 046 1:1
#   अतः परं प्रवक्ष्यामि रौरवं नरकं पुनः
#   ataḥ paraṃ pravakṣyāmi rauravaṃ narakaṃ punaḥ
#
# similarity 0.8115942028985508:
# 167S 113:1
#   क्षीणे कृतयुगे व्यास त्रेतायुगमुखोदये
#   kṣīṇe kṛtayuge vyāsa tretāyugamukhodaye
# 167RA5 47:1
#   क्षीणे कृतयुगे व्यास त्रेतायुग उपस्थिते
#   kṣīṇe kṛtayuge vyāsa tretāyuga upasthite
#
# similarity 0.8108108108108109:
# 050 15:2
#   ततो गोत्वं समासाद्य मानुष्यं प्राप्नुवन्ति ते
#   tato gotvaṃ samāsādya mānuṣyaṃ prāpnuvanti te
# 050 32:2
#   ततो गोत्वं समासाद्य मानुषत्वमवाप्नुते
#   tato gotvaṃ samāsādya mānuṣatvamavāpnute
#
# similarity 0.8076923076923077:
# 014 2:2
#   नमः पवनवेगाय विरूपायाजिताय च
#   namaḥ pavanavegāya virūpāyājitāya ca
# 024 56:1
#   नमः पवनवेगाय सर्वज्ञायाजिताय च
#   namaḥ pavanavegāya sarvajñāyājitāya ca
#
# similarity 0.8070175438596491:
# 015 19:1
#   नमः कनकलिङ्गाय वेदलिङ्गाय वै नमः
#   namaḥ kanakaliṅgāya vedaliṅgāya vai namaḥ
# 015 26:1
#   नमो गगनलिङ्गाय तेजोलिङ्गाय वै नमः
#   namo gaganaliṅgāya tejoliṅgāya vai namaḥ
#
# similarity 0.8059701492537313:
# 015 18:2
#   शिरस्यञ्जलिमाधाय तुष्टाव हृषिताननः
#   śirasyañjalimādhāya tuṣṭāva hṛṣitānanaḥ
# 029 185:2
#   शिरस्यञ्जलिमाधाय तुष्टुवुः सहिताः समम्
#   śirasyañjalimādhāya tuṣṭuvuḥ sahitāḥ samam
#
# similarity 0.8055555555555556:
# 009 9:1
#   नमो नरस्य कर्त्रे च स्थितिकर्त्रे नमः सदा
#   namo narasya kartre ca sthitikartre namaḥ sadā
# 014 17:1
#   नमो ऽनुग्रहकर्त्रे च स्थितिकर्त्रे नमो नमः
#   namo 'nugrahakartre ca sthitikartre namo namaḥ
#
# similarity 0.8051948051948052:
# 167S 84:1
#   देवदेवस्य रुद्रस्य यत्र सांनिध्यमुत्तमम्
#   devadevasya rudrasya yatra sāṃnidhyamuttamam
# 167RA4 25:1
#   साम्बिकस्य तु रुद्रस्य यत्र सांनिध्यमुत्तमम्
#   sāmbikasya tu rudrasya yatra sāṃnidhyamuttamam
#
# similarity 0.8:
# 167S 128:1
#   तत्र प्रथममादाय शिष्यं कौशिकमीश्वरः
#   tatra prathamamādāya śiṣyaṃ kauśikamīśvaraḥ
# 167RA5 86:1
#   तत्र प्रथममादाय शिष्यं शिष्यविदां वरः
#   tatra prathamamādāya śiṣyaṃ śiṣyavidāṃ varaḥ
#
# similarity 0.8:
# 031 109:2
#   अश्वमेधफलं ह्यत्र स्नातः प्राप्नोति पुष्कलम्
#   aśvamedhaphalaṃ hyatra snātaḥ prāpnoti puṣkalam
# 032 152:1
#   अश्वमेधफलं तत्र स्नातः प्राप्नोति मानवः
#   aśvamedhaphalaṃ tatra snātaḥ prāpnoti mānavaḥ
#
# similarity 0.8:
# 050 16:1
#   षष्ठाच्चैव विनिर्मुक्तास्ततः शेषेण कर्मणा
#   ṣaṣṭhāccaiva vinirmuktāstataḥ śeṣeṇa karmaṇā
# 050 20:1
#   अष्टमाच्च विनिर्मुक्तो बद्धः शेषेण कर्मणा
#   aṣṭamācca vinirmukto baddhaḥ śeṣeṇa karmaṇā
#
# similarity 0.8:
# 049 28:1
#   य इमं तामसं घोरं शृणुयाद्वा पठेत वा
#   ya imaṃ tāmasaṃ ghoraṃ śṛṇuyādvā paṭheta vā
# 051 42:1
#   य इमं नारकोत्तारं शृणुयाद्वा पठेत वा
#   ya imaṃ nārakottāraṃ śṛṇuyādvā paṭheta vā
